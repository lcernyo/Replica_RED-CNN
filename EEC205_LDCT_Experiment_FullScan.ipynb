# %% [markdown]
# Imports/Install -- Required Packages
#
# OBS: All code was written by Luca Cerny Oliveira unless especified as a comment

# %%
### Cell to link Notebook to Google Drive

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.7/dist-packages (2.2.2)

# %%
pip install pypng
# Out:
# Requirement already satisfied: pypng in /usr/local/lib/python3.7/dist-packages (0.0.21)

# %%
# Core imports
import os
import pandas as pd
import numpy as np
import random

# Imports for benchmarking/plotting
import matplotlib.pyplot as plt
import statistics
import time 

# DataLoader
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# Deep Learning
import torch
import torch.nn as nn
import torchvision.transforms.functional as F
from torch.optim.lr_scheduler import StepLR


# .DIM to .PNG 
import pydicom
import cv2
import PIL
import csv
import png
from skimage import io, transform
from google.colab.patches import cv2_imshow

# %% [markdown]
# # **1st Part: Loading and Setting-up data**
#
# Loading data:
# *   Images will be Greyscale
# *   CT scans are 256x256 Images
# *   Patches are 55x55 Images

# %%
#The below function NEEDS to be done separately so it does not have to convert from DICOM everytime
def dcm_path_to_jpg(path,save_path):
  ds = pydicom.read_file(path) # read dicom image
  img = ds.pixel_array # get image array

  ### this normalization expression for dicom to png was taken from
  ### https://pycad.co/how-to-convert-a-dicom-image-into-jpg-or-png/
  img = (np.maximum(img, 0) / img.max()) * 255.0

  img = np.uint8(img)

  cv2.imwrite(save_path,img) # write png image

# %%
dicom_path = '/content/drive/MyDrive/CT_Project/LungCT/'
save_path = '/content/drive/MyDrive/CT_Project/fixedCT/'

for case in sorted(os.listdir(dicom_path)):
  print(case) #make new directory on clean folder
  subpath1 = dicom_path+case+'/'
  save_folder = save_path + case + '/'
  if not(os.path.isdir(save_folder)):
    os.makedirs(save_folder)
  subpath2 = subpath1 + os.listdir(subpath1)[0] + '/' # here is the information for pixel intensity (my guess)
  subpath3 = subpath2 + os.listdir(subpath2)[0] + '/'
  for dcm_img in sorted(os.listdir(subpath3)):
    print(subpath3+dcm_img)
    filename = dcm_img.split('.')[0]
    dcm_file = subpath3 + dcm_img
    save_file = save_folder + filename + '.png'
    dcm_path_to_jpg(dcm_file, save_file)
# Out:
# R_004
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-01.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-02.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-03.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-04.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-05.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-06.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-07.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-08.dcm
# /content/drive/MyDrive/CT_Project/LungCT/R_004/06-30-1997-NA-Diagnostic Pre-Surgery Contrast Enhanced CT-71813/3.000000- NONE -29295/1-09.dcm

# %%
### Amount of cases available in dataset + case names:
dataset_folder_path = '/content/drive/MyDrive/CT_Project/fixedCT/'

sorted(os.listdir(dataset_folder_path))

# %%
transform=transforms.Compose([transforms.Grayscale(num_output_channels=1),
                              transforms.Resize(256),
                              transforms.ToTensor()
                              ])

# %%
class CT_Scan(Dataset):
    """Lung CT Scan Dataset"""

    def __init__(self, path, cases, transform=None):
        """
        Args:
            path (string): Folder with all images separated by case
            cases (string list): Cases that will be used
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.path = path
        self.cases = cases
        self.transform = transform

        self.path_list = self.count_cases(self.path, self.cases)

    def count_cases(self,path,cases):
        #Parse through cases folders
        path_list = []
        for case in sorted(os.listdir(path)):
          if case in cases:
            for img_path in sorted(os.listdir(path + case + '/')):
              path_list.append(path + case + '/'+img_path)

        return path_list

    def __len__(self):
        return len(self.path_list)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()


        image = io.imread(self.path_list[idx])

        noisy = image
        noisy = np.random.poisson(noisy / 255.0 * 100) / 100 * 255  # noisy image

        image = PIL.Image.fromarray(image)

        noisy = PIL.Image.fromarray(noisy)

        if self.transform:
            image = self.transform(image)
            noisy = self.transform(noisy)

        sample = {'image': image, 'noisy': noisy}

        if random.random() > 0.5:
          image = F.hflip(image)
          noisy = F.hflip(noisy)
        
        if random.random() > 0.25:
          image = F.vflip(image)
          noisy = F.vflip(noisy)

        return sample

# %%
LungDataset = CT_Scan(path = '/content/drive/MyDrive/CT_Project/fixedCT/', cases = ['R_259'], transform = transform)

# %%
for idx in range(len(LungDataset)):
  sample_data = LungDataset[idx]
  sample_img, sample_noisy = sample_data['image'], sample_data['noisy']

  if idx == 10:
    print(sample_img.size())
    print(sample_img)
    plt.imshow(sample_img[0],cmap='gray',vmin=0,vmax=1)
    break
# Out:
# torch.Size([1, 256, 256])
# tensor([[[0.0039, 0.0078, 0.0078,  ..., 0.0039, 0.0078, 0.0078],
#          [0.0078, 0.0078, 0.0078,  ..., 0.0039, 0.0078, 0.0078],
#          [0.0078, 0.0078, 0.0078,  ..., 0.0078, 0.0078, 0.0078],
#          ...,
#          [0.0431, 0.0431, 0.0431,  ..., 0.3647, 0.4118, 0.4118],
#          [0.0431, 0.0431, 0.0431,  ..., 0.3961, 0.3255, 0.2353],
#          [0.0431, 0.0471, 0.0431,  ..., 0.2196, 0.1294, 0.0667]]])

# %%
print(sample_noisy.size())
print(sample_noisy)
plt.imshow(sample_noisy[0],cmap='gray',vmin=0,vmax=1)
# Out:
# torch.Size([1, 256, 256])
# tensor([[[0.0078, 0.0118, 0.0078,  ..., 0.0039, 0.0078, 0.0039],
#          [0.0078, 0.0078, 0.0039,  ..., 0.0039, 0.0039, 0.0078],
#          [0.0078, 0.0039, 0.0000,  ..., 0.0039, 0.0000, 0.0000],
#          ...,
#          [0.0353, 0.0510, 0.0431,  ..., 0.3608, 0.4275, 0.4471],
#          [0.0431, 0.0471, 0.0431,  ..., 0.4039, 0.2941, 0.2471],
#          [0.0471, 0.0549, 0.0588,  ..., 0.2196, 0.1255, 0.0667]]])

# %%
ctloader = DataLoader(LungDataset, batch_size = 50, suffle = True, num_workers=0, drop_last = False)

# %% [markdown]
# # **2nd Part: Model, Fit and Evaluation Function Design**

# %%
class DNN(nn.Module):
  def __init__(self):
    super(DNN, self).__init__()
    self.relu = nn.ReLU()

    self.conv1 = nn.Conv2d(1, 64, kernel_size=3)
    self.bn1 = nn.BatchNorm2d(64)
    self.conv2 = nn.Conv2d(64, 128, kernel_size=3)
    self.bn2 = nn.BatchNorm2d(128)
    self.conv3 = nn.Conv2d(128, 256, kernel_size=3)
    self.bn3 = nn.BatchNorm2d(256)
    self.conv4 = nn.Conv2d(256, 512, kernel_size=3)
    self.bn4 = nn.BatchNorm2d(512)
    self.conv5 = nn.Conv2d(512, 1024, kernel_size=3)
    self.bn5 = nn.BatchNorm2d(1024)

    self.deconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=3)
    self.bn6 = nn.BatchNorm2d(512)
    self.deconv2 = nn.ConvTranspose2d(512, 256, kernel_size=3)
    self.bn7 = nn.BatchNorm2d(256)
    self.deconv3 = nn.ConvTranspose2d(256, 128, kernel_size=3)
    self.bn8 = nn.BatchNorm2d(128)
    self.deconv4 = nn.ConvTranspose2d(128, 64, kernel_size=3)
    self.bn9 = nn.BatchNorm2d(64)
    self.deconv5 = nn.ConvTranspose2d(64, 1, kernel_size=3)
  
  def forward(self,x):
    r1 = x
    out = self.conv1(x)
    out = self.relu(out)
    out = self.bn1(out)

    out = self.conv2(out)
    out = self.relu(out)
    out = self.bn2(out)

    r2 = out
    out = self.conv3(out)
    out = self.relu(out)
    out = self.bn3(out)

    out = self.conv4(out)
    out = self.relu(out)
    out = self.bn4(out)

    r3 = out
    out = self.conv5(out)
    out = self.relu(out)
    out = self.bn5(out)


    out = self.deconv1(out)
    out = out + r3
    out = self.relu(out)
    out = self.bn6(out)

    out = self.deconv2(out)
    out = self.relu(out)
    out = self.bn7(out)
    
    out = self.deconv3(out)
    out = out + r2
    out = self.relu(out)
    out = self.bn8(out)

    out = self.deconv4(out)
    out = self.relu(out)
    out = self.bn9(out)

    out = self.deconv5(out)
    out = out + r1
    out = self.relu(out)

    return out

# %%
def randomInit(m):
  print("Model Randomly Initialized")
  if isinstance(m, nn.Linear):
    torch.nn.init.xavier_uniform_(m.weight)
    torch.nn.init.zeros_(m.bias)


def fit(model, loss_fn, optimizer, train_loader, batch_size, num_epochs, stat_count = 100,device = None, PATH = '/content/drive/MyDrive/CT_Project/model.pt'):
  if device is not None:
    model.to(device)
  else:
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    model.to(device)

  randomInit(model)

  scheduler = StepLR(optimizer, step_size = 5, gamma=0.1)

  epoch_loss = []
  train_acc = []

  for epoch in range(num_epochs):
    if epoch != 0:
      mse_eval = []
      scheduler.step()
      epoch_loss.append(loss.item())
      print("End of epoch")
      for train_data in train_loader:
        with torch.no_grad():
          model.eval()
          trainimg, trainnsy = train_data['image'].cuda(), train_data['noisy'].cuda()
          trainoutputs = model(trainnsy)
          mse = loss_fn(trainoutputs, trainimg).item()
          mse_eval.append(mse)
      if statistics.mean(mse_eval) < model_score:
        print("Score of ", mse, "is the best yet. Saving model ...")
        model_score = mse
        torch.save({'model_state_dict': model.state_dict()}, PATH)
      train_acc.append(mse)
    else:
      model_score = 100000 
    for i, data in enumerate(train_loader, 0):
      with torch.enable_grad():
        model.train()
        images, noisy = data['image'].cuda(), data['noisy'].cuda()

        optimizer.zero_grad()

        outputs = model(noisy)

        loss = loss_fn(outputs, images)

        loss.backward()
        optimizer.step()

        if (i+1) % stat_count == 0:
          print('Epoch [%d/%d], Step [%d/%d], Loss: %.4f'%(epoch+1, num_epochs, i+1, len(train_loader), loss.item()))

  return epoch_loss, train_acc

    

def test(model, test_loader, loss_fn,  batch_size = 1, sample_idx = 0, device = None, PATH = '/content/drive/MyDrive/CT_Project/model.pt'):
  checkpoint = torch.load(PATH)
  model.load_state_dict(checkpoint['model_state_dict'])
  if device is not None:
    model.to(device)
  else:
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    model.to(device)

  ct = 0
  mse_list = []
  mse_noisy = []
  with torch.no_grad():
    model.eval()
    for test_data in test_loader:
      images, noisy = test_data['image'].cuda(), test_data['noisy'].cuda()

      outputs = model(noisy)

      mse_obj = loss_fn(outputs, images)
      mse = mse_obj.item()
      mse_list.append(mse)

      mse_n_obj = loss_fn(noisy, images)
      mse_n = mse_n_obj.item()
      mse_noisy.append(mse_n)

      if ct == sample_idx:
        denoised = outputs
        LDCT = noisy
        image = images

      ct += 1

  print("Average MSE Loss = ", statistics.mean(mse_list))

  return mse_list, mse_noisy, denoised, LDCT, image

# %% [markdown]
# # **3rd Part: Inference**

# %%
num_epochs = 25
batch_size = 7


model = DNN()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

# %%
transform=transforms.Compose([transforms.Grayscale(num_output_channels=1),
                              transforms.Resize(256),
                              transforms.ToTensor()
                              ])


cases_to_train = ['R_004','R_006','R_013','R_014','R_019','R_020','R_022','R_029','R_033','R_035','R_036','R_043','R_053','R_056','R_061','R_064','R_065','R_066','R_069','R_075','R_077','R_078',
 'R_093','R_098','R_102','R_108','R_111','R_116','R_117','R_124','R_126','R_127','R_137','R_141','R_143','R_146','R_150','R_157','R_168','R_170','R_172','R_175','R_180','R_185','R_191','R_193',
 'R_208','R_209','R_210','R_214','R_232','R_233','R_237','R_239','R_256','R_266','R_267','R_273','R_274']

cases_to_test = ['R_144', 'R_259']

for case in cases_to_test:
  if case in cases_to_train:
    print(case)
    print("!!!DO NOT PROCEED!!!")
    print("Scans from the hold-out test set leaked into the train set. Reselect cases")

LungDataset = CT_Scan(path = '/content/drive/MyDrive/CT_Project/fixedCT/', cases = cases_to_train, transform = transform)

TestCase = CT_Scan(path = '/content/drive/MyDrive/CT_Project/fixedCT/', cases = cases_to_test, transform = transform)

train_loader = DataLoader(LungDataset, batch_size = batch_size, shuffle = True, drop_last = True)

test_loader = DataLoader(TestCase, batch_size = 1, shuffle = False, drop_last = True)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# DNN(
#   (relu): ReLU()
#   (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1))
#   (bn5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv1): ConvTranspose2d(1024, 512, kernel_size=(3, 3), stride=(1, 1))
#   (bn6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#   (bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (bn8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv4): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv5): ConvTranspose2d(64, 1, kernel_size=(3, 3), stride=(1, 1))
# )

# %%
start = time.time()

epoch_loss, train_acc = fit(model, loss_fn, optimizer, train_loader, batch_size, num_epochs, stat_count = 10,device = None, PATH = '/content/drive/MyDrive/CT_Project/model_var_ker.pt')

end = time.time()
# Out:
# Model Randomly Initialized
# Epoch [1/25], Step [10/647], Loss: 1.1497
# Epoch [1/25], Step [20/647], Loss: 0.3454
# Epoch [1/25], Step [30/647], Loss: 0.2590
# Epoch [1/25], Step [40/647], Loss: 0.1903
# Epoch [1/25], Step [50/647], Loss: 0.1304
# Epoch [1/25], Step [60/647], Loss: 0.1048
# Epoch [1/25], Step [70/647], Loss: 0.0980
# Epoch [1/25], Step [80/647], Loss: 0.0826
# Epoch [1/25], Step [90/647], Loss: 0.0801
# Epoch [1/25], Step [100/647], Loss: 0.0742
# Epoch [1/25], Step [110/647], Loss: 0.0716
# Epoch [1/25], Step [120/647], Loss: 0.0571
# Epoch [1/25], Step [130/647], Loss: 0.0564
# Epoch [1/25], Step [140/647], Loss: 0.0586
# Epoch [1/25], Step [150/647], Loss: 0.0519
# Epoch [1/25], Step [160/647], Loss: 0.0567
# Epoch [1/25], Step [170/647], Loss: 0.0348
# Epoch [1/25], Step [180/647], Loss: 0.0403
# Epoch [1/25], Step [190/647], Loss: 0.0615
# Epoch [1/25], Step [200/647], Loss: 0.0267
# Epoch [1/25], Step [210/647], Loss: 0.0270
# Epoch [1/25], Step [220/647], Loss: 0.0221
# Epoch [1/25], Step [230/647], Loss: 0.0246
# Epoch [1/25], Step [240/647], Loss: 0.0346
# Epoch [1/25], Step [250/647], Loss: 0.0285
# Epoch [1/25], Step [260/647], Loss: 0.0386
# Epoch [1/25], Step [270/647], Loss: 0.0207
# Epoch [1/25], Step [280/647], Loss: 0.0292
# Epoch [1/25], Step [290/647], Loss: 0.0203
# Epoch [1/25], Step [300/647], Loss: 0.0558
# Epoch [1/25], Step [310/647], Loss: 0.0405
# Epoch [1/25], Step [320/647], Loss: 0.0250
# Epoch [1/25], Step [330/647], Loss: 0.0188
# Epoch [1/25], Step [340/647], Loss: 0.0306
# Epoch [1/25], Step [350/647], Loss: 0.0178
# Epoch [1/25], Step [360/647], Loss: 0.0119
# Epoch [1/25], Step [370/647], Loss: 0.0089
# Epoch [1/25], Step [380/647], Loss: 0.0249
# Epoch [1/25], Step [390/647], Loss: 0.0135
# Epoch [1/25], Step [400/647], Loss: 0.0159
# Epoch [1/25], Step [410/647], Loss: 0.0209
# Epoch [1/25], Step [420/647], Loss: 0.0127
# Epoch [1/25], Step [430/647], Loss: 0.0119
# Epoch [1/25], Step [440/647], Loss: 0.0146
# Epoch [1/25], Step [450/647], Loss: 0.0136
# Epoch [1/25], Step [460/647], Loss: 0.0148
# Epoch [1/25], Step [470/647], Loss: 0.0119
# Epoch [1/25], Step [480/647], Loss: 0.0121
# Epoch [1/25], Step [490/647], Loss: 0.0125
# Epoch [1/25], Step [500/647], Loss: 0.0104
# Epoch [1/25], Step [510/647], Loss: 0.0122
# Epoch [1/25], Step [520/647], Loss: 0.0143
# Epoch [1/25], Step [530/647], Loss: 0.0142
# Epoch [1/25], Step [540/647], Loss: 0.0159
# Epoch [1/25], Step [550/647], Loss: 0.0122
# Epoch [1/25], Step [560/647], Loss: 0.0130
# Epoch [1/25], Step [570/647], Loss: 0.0115
# Epoch [1/25], Step [580/647], Loss: 0.0143
# Epoch [1/25], Step [590/647], Loss: 0.0116
# Epoch [1/25], Step [600/647], Loss: 0.0080
# Epoch [1/25], Step [610/647], Loss: 0.0101
# Epoch [1/25], Step [620/647], Loss: 0.0137
# Epoch [1/25], Step [630/647], Loss: 0.0070
# Epoch [1/25], Step [640/647], Loss: 0.0117
# End of epoch
# Score of  0.013394508510828018 is the best yet. Saving model ...
# Epoch [2/25], Step [10/647], Loss: 0.0077
# Epoch [2/25], Step [20/647], Loss: 0.0097
# Epoch [2/25], Step [30/647], Loss: 0.0066
# Epoch [2/25], Step [40/647], Loss: 0.0099
# Epoch [2/25], Step [50/647], Loss: 0.0051
# Epoch [2/25], Step [60/647], Loss: 0.0089
# Epoch [2/25], Step [70/647], Loss: 0.0137
# Epoch [2/25], Step [80/647], Loss: 0.0073
# Epoch [2/25], Step [90/647], Loss: 0.0078
# Epoch [2/25], Step [100/647], Loss: 0.0069
# Epoch [2/25], Step [110/647], Loss: 0.0209
# Epoch [2/25], Step [120/647], Loss: 0.0069
# Epoch [2/25], Step [130/647], Loss: 0.0132
# Epoch [2/25], Step [140/647], Loss: 0.0073
# Epoch [2/25], Step [150/647], Loss: 0.0076
# Epoch [2/25], Step [160/647], Loss: 0.0075
# Epoch [2/25], Step [170/647], Loss: 0.0072
# Epoch [2/25], Step [180/647], Loss: 0.0057
# Epoch [2/25], Step [190/647], Loss: 0.0058
# Epoch [2/25], Step [200/647], Loss: 0.0083
# Epoch [2/25], Step [210/647], Loss: 0.0081
# Epoch [2/25], Step [220/647], Loss: 0.0096
# Epoch [2/25], Step [230/647], Loss: 0.0068
# Epoch [2/25], Step [240/647], Loss: 0.0093
# Epoch [2/25], Step [250/647], Loss: 0.0073
# Epoch [2/25], Step [260/647], Loss: 0.0067
# Epoch [2/25], Step [270/647], Loss: 0.0058
# Epoch [2/25], Step [280/647], Loss: 0.0056
# Epoch [2/25], Step [290/647], Loss: 0.0070
# Epoch [2/25], Step [300/647], Loss: 0.0112
# Epoch [2/25], Step [310/647], Loss: 0.0073
# Epoch [2/25], Step [320/647], Loss: 0.0072
# Epoch [2/25], Step [330/647], Loss: 0.0089
# Epoch [2/25], Step [340/647], Loss: 0.0056
# Epoch [2/25], Step [350/647], Loss: 0.0059
# Epoch [2/25], Step [360/647], Loss: 0.0085
# Epoch [2/25], Step [370/647], Loss: 0.0054
# Epoch [2/25], Step [380/647], Loss: 0.0038
# Epoch [2/25], Step [390/647], Loss: 0.0052
# Epoch [2/25], Step [400/647], Loss: 0.0045
# Epoch [2/25], Step [410/647], Loss: 0.0045
# Epoch [2/25], Step [420/647], Loss: 0.0064
# Epoch [2/25], Step [430/647], Loss: 0.0040
# Epoch [2/25], Step [440/647], Loss: 0.0061
# Epoch [2/25], Step [450/647], Loss: 0.0057
# Epoch [2/25], Step [460/647], Loss: 0.0039
# Epoch [2/25], Step [470/647], Loss: 0.0047
# Epoch [2/25], Step [480/647], Loss: 0.0075
# Epoch [2/25], Step [490/647], Loss: 0.0052
# Epoch [2/25], Step [500/647], Loss: 0.0042
# Epoch [2/25], Step [510/647], Loss: 0.0054
# Epoch [2/25], Step [520/647], Loss: 0.0080
# Epoch [2/25], Step [530/647], Loss: 0.0056
# Epoch [2/25], Step [540/647], Loss: 0.0050
# Epoch [2/25], Step [550/647], Loss: 0.0046
# Epoch [2/25], Step [560/647], Loss: 0.0040
# Epoch [2/25], Step [570/647], Loss: 0.0046
# Epoch [2/25], Step [580/647], Loss: 0.0053
# Epoch [2/25], Step [590/647], Loss: 0.0063
# Epoch [2/25], Step [600/647], Loss: 0.0039
# Epoch [2/25], Step [610/647], Loss: 0.0055
# Epoch [2/25], Step [620/647], Loss: 0.0048
# Epoch [2/25], Step [630/647], Loss: 0.0039
# Epoch [2/25], Step [640/647], Loss: 0.0140
# End of epoch
# Score of  0.0030960021540522575 is the best yet. Saving model ...
# Epoch [3/25], Step [10/647], Loss: 0.0079
# Epoch [3/25], Step [20/647], Loss: 0.0062
# Epoch [3/25], Step [30/647], Loss: 0.0067
# Epoch [3/25], Step [40/647], Loss: 0.0068
# Epoch [3/25], Step [50/647], Loss: 0.0052
# Epoch [3/25], Step [60/647], Loss: 0.0085
# Epoch [3/25], Step [70/647], Loss: 0.0035
# Epoch [3/25], Step [80/647], Loss: 0.0042
# Epoch [3/25], Step [90/647], Loss: 0.0055
# Epoch [3/25], Step [100/647], Loss: 0.0056
# Epoch [3/25], Step [110/647], Loss: 0.0038
# Epoch [3/25], Step [120/647], Loss: 0.0043
# Epoch [3/25], Step [130/647], Loss: 0.0038
# Epoch [3/25], Step [140/647], Loss: 0.0056
# Epoch [3/25], Step [150/647], Loss: 0.0039
# Epoch [3/25], Step [160/647], Loss: 0.0065
# Epoch [3/25], Step [170/647], Loss: 0.0046
# Epoch [3/25], Step [180/647], Loss: 0.0025
# Epoch [3/25], Step [190/647], Loss: 0.0032
# Epoch [3/25], Step [200/647], Loss: 0.0042
# Epoch [3/25], Step [210/647], Loss: 0.0037
# Epoch [3/25], Step [220/647], Loss: 0.0051
# Epoch [3/25], Step [230/647], Loss: 0.0042
# Epoch [3/25], Step [240/647], Loss: 0.0068
# Epoch [3/25], Step [250/647], Loss: 0.0048
# Epoch [3/25], Step [260/647], Loss: 0.0052
# Epoch [3/25], Step [270/647], Loss: 0.0044
# Epoch [3/25], Step [280/647], Loss: 0.0048
# Epoch [3/25], Step [290/647], Loss: 0.0047
# Epoch [3/25], Step [300/647], Loss: 0.0053
# Epoch [3/25], Step [310/647], Loss: 0.0048
# Epoch [3/25], Step [320/647], Loss: 0.0064
# Epoch [3/25], Step [330/647], Loss: 0.0042
# Epoch [3/25], Step [340/647], Loss: 0.0064
# Epoch [3/25], Step [350/647], Loss: 0.0040
# Epoch [3/25], Step [360/647], Loss: 0.0030
# Epoch [3/25], Step [370/647], Loss: 0.0048
# Epoch [3/25], Step [380/647], Loss: 0.0070
# Epoch [3/25], Step [390/647], Loss: 0.0043
# Epoch [3/25], Step [400/647], Loss: 0.0060
# Epoch [3/25], Step [410/647], Loss: 0.0039
# Epoch [3/25], Step [420/647], Loss: 0.0037
# Epoch [3/25], Step [430/647], Loss: 0.0027
# Epoch [3/25], Step [440/647], Loss: 0.0041
# Epoch [3/25], Step [450/647], Loss: 0.0029
# Epoch [3/25], Step [460/647], Loss: 0.0075
# Epoch [3/25], Step [470/647], Loss: 0.0042
# Epoch [3/25], Step [480/647], Loss: 0.0048
# Epoch [3/25], Step [490/647], Loss: 0.0063
# Epoch [3/25], Step [500/647], Loss: 0.0054
# Epoch [3/25], Step [510/647], Loss: 0.0060
# Epoch [3/25], Step [520/647], Loss: 0.0037
# Epoch [3/25], Step [530/647], Loss: 0.0048
# Epoch [3/25], Step [540/647], Loss: 0.0064
# Epoch [3/25], Step [550/647], Loss: 0.0047
# Epoch [3/25], Step [560/647], Loss: 0.0030
# Epoch [3/25], Step [570/647], Loss: 0.0046
# Epoch [3/25], Step [580/647], Loss: 0.0057
# Epoch [3/25], Step [590/647], Loss: 0.0039
# Epoch [3/25], Step [600/647], Loss: 0.0033
# Epoch [3/25], Step [610/647], Loss: 0.0033
# Epoch [3/25], Step [620/647], Loss: 0.0051
# Epoch [3/25], Step [630/647], Loss: 0.0020
# Epoch [3/25], Step [640/647], Loss: 0.0031
# End of epoch
# Epoch [4/25], Step [10/647], Loss: 0.0071
# Epoch [4/25], Step [20/647], Loss: 0.0035
# Epoch [4/25], Step [30/647], Loss: 0.0057
# Epoch [4/25], Step [40/647], Loss: 0.0033
# Epoch [4/25], Step [50/647], Loss: 0.0024
# Epoch [4/25], Step [60/647], Loss: 0.0030
# Epoch [4/25], Step [70/647], Loss: 0.0042
# Epoch [4/25], Step [80/647], Loss: 0.0056
# Epoch [4/25], Step [90/647], Loss: 0.0027
# Epoch [4/25], Step [100/647], Loss: 0.0043
# Epoch [4/25], Step [110/647], Loss: 0.0038
# Epoch [4/25], Step [120/647], Loss: 0.0035
# Epoch [4/25], Step [130/647], Loss: 0.0021
# Epoch [4/25], Step [140/647], Loss: 0.0069
# Epoch [4/25], Step [150/647], Loss: 0.0023
# Epoch [4/25], Step [160/647], Loss: 0.0029
# Epoch [4/25], Step [170/647], Loss: 0.0020
# Epoch [4/25], Step [180/647], Loss: 0.0064
# Epoch [4/25], Step [190/647], Loss: 0.0038
# Epoch [4/25], Step [200/647], Loss: 0.0045
# Epoch [4/25], Step [210/647], Loss: 0.0055
# Epoch [4/25], Step [220/647], Loss: 0.0050
# Epoch [4/25], Step [230/647], Loss: 0.0042
# Epoch [4/25], Step [240/647], Loss: 0.0047
# Epoch [4/25], Step [250/647], Loss: 0.0030
# Epoch [4/25], Step [260/647], Loss: 0.0051
# Epoch [4/25], Step [270/647], Loss: 0.0047
# Epoch [4/25], Step [280/647], Loss: 0.0028
# Epoch [4/25], Step [290/647], Loss: 0.0041
# Epoch [4/25], Step [300/647], Loss: 0.0048
# Epoch [4/25], Step [310/647], Loss: 0.0054
# Epoch [4/25], Step [320/647], Loss: 0.0061
# Epoch [4/25], Step [330/647], Loss: 0.0047
# Epoch [4/25], Step [340/647], Loss: 0.0082
# Epoch [4/25], Step [350/647], Loss: 0.0043
# Epoch [4/25], Step [360/647], Loss: 0.0045
# Epoch [4/25], Step [370/647], Loss: 0.0063
# Epoch [4/25], Step [380/647], Loss: 0.0037
# Epoch [4/25], Step [390/647], Loss: 0.0056
# Epoch [4/25], Step [400/647], Loss: 0.0074
# Epoch [4/25], Step [410/647], Loss: 0.0035
# Epoch [4/25], Step [420/647], Loss: 0.0028
# Epoch [4/25], Step [430/647], Loss: 0.0054
# Epoch [4/25], Step [440/647], Loss: 0.0041
# Epoch [4/25], Step [450/647], Loss: 0.0049
# Epoch [4/25], Step [460/647], Loss: 0.0052
# Epoch [4/25], Step [470/647], Loss: 0.0042
# Epoch [4/25], Step [480/647], Loss: 0.0053
# Epoch [4/25], Step [490/647], Loss: 0.0083
# Epoch [4/25], Step [500/647], Loss: 0.0044
# Epoch [4/25], Step [510/647], Loss: 0.0032
# Epoch [4/25], Step [520/647], Loss: 0.0037
# Epoch [4/25], Step [530/647], Loss: 0.0029
# Epoch [4/25], Step [540/647], Loss: 0.0027
# Epoch [4/25], Step [550/647], Loss: 0.0044
# Epoch [4/25], Step [560/647], Loss: 0.0043
# Epoch [4/25], Step [570/647], Loss: 0.0033
# Epoch [4/25], Step [580/647], Loss: 0.0043
# Epoch [4/25], Step [590/647], Loss: 0.0024
# Epoch [4/25], Step [600/647], Loss: 0.0039
# Epoch [4/25], Step [610/647], Loss: 0.0030
# Epoch [4/25], Step [620/647], Loss: 0.0035
# Epoch [4/25], Step [630/647], Loss: 0.0031
# Epoch [4/25], Step [640/647], Loss: 0.0049
# End of epoch
# Epoch [5/25], Step [10/647], Loss: 0.0028
# Epoch [5/25], Step [20/647], Loss: 0.0018
# Epoch [5/25], Step [30/647], Loss: 0.0024
# Epoch [5/25], Step [40/647], Loss: 0.0025
# Epoch [5/25], Step [50/647], Loss: 0.0039
# Epoch [5/25], Step [60/647], Loss: 0.0019
# Epoch [5/25], Step [70/647], Loss: 0.0028
# Epoch [5/25], Step [80/647], Loss: 0.0066
# Epoch [5/25], Step [90/647], Loss: 0.0039
# Epoch [5/25], Step [100/647], Loss: 0.0027
# Epoch [5/25], Step [110/647], Loss: 0.0023
# Epoch [5/25], Step [120/647], Loss: 0.0038
# Epoch [5/25], Step [130/647], Loss: 0.0039
# Epoch [5/25], Step [140/647], Loss: 0.0029
# Epoch [5/25], Step [150/647], Loss: 0.0059
# Epoch [5/25], Step [160/647], Loss: 0.0046
# Epoch [5/25], Step [170/647], Loss: 0.0041
# Epoch [5/25], Step [180/647], Loss: 0.0049
# Epoch [5/25], Step [190/647], Loss: 0.0031
# Epoch [5/25], Step [200/647], Loss: 0.0038
# Epoch [5/25], Step [210/647], Loss: 0.0064
# Epoch [5/25], Step [220/647], Loss: 0.0039
# Epoch [5/25], Step [230/647], Loss: 0.0044
# Epoch [5/25], Step [240/647], Loss: 0.0035
# Epoch [5/25], Step [250/647], Loss: 0.0029
# Epoch [5/25], Step [260/647], Loss: 0.0045
# Epoch [5/25], Step [270/647], Loss: 0.0029
# Epoch [5/25], Step [280/647], Loss: 0.0027
# Epoch [5/25], Step [290/647], Loss: 0.0031
# Epoch [5/25], Step [300/647], Loss: 0.0039
# Epoch [5/25], Step [310/647], Loss: 0.0029
# Epoch [5/25], Step [320/647], Loss: 0.0022
# Epoch [5/25], Step [330/647], Loss: 0.0028
# Epoch [5/25], Step [340/647], Loss: 0.0061
# Epoch [5/25], Step [350/647], Loss: 0.0053
# Epoch [5/25], Step [360/647], Loss: 0.0038
# Epoch [5/25], Step [370/647], Loss: 0.0032
# Epoch [5/25], Step [380/647], Loss: 0.0031
# Epoch [5/25], Step [390/647], Loss: 0.0024
# Epoch [5/25], Step [400/647], Loss: 0.0027
# Epoch [5/25], Step [410/647], Loss: 0.0034
# Epoch [5/25], Step [420/647], Loss: 0.0048
# Epoch [5/25], Step [430/647], Loss: 0.0040
# Epoch [5/25], Step [440/647], Loss: 0.0029
# Epoch [5/25], Step [450/647], Loss: 0.0038
# Epoch [5/25], Step [460/647], Loss: 0.0047
# Epoch [5/25], Step [470/647], Loss: 0.0027
# Epoch [5/25], Step [480/647], Loss: 0.0022
# Epoch [5/25], Step [490/647], Loss: 0.0028
# Epoch [5/25], Step [500/647], Loss: 0.0029
# Epoch [5/25], Step [510/647], Loss: 0.0017
# Epoch [5/25], Step [520/647], Loss: 0.0020
# Epoch [5/25], Step [530/647], Loss: 0.0025
# Epoch [5/25], Step [540/647], Loss: 0.0036
# Epoch [5/25], Step [550/647], Loss: 0.0020
# Epoch [5/25], Step [560/647], Loss: 0.0026
# Epoch [5/25], Step [570/647], Loss: 0.0040
# Epoch [5/25], Step [580/647], Loss: 0.0027
# Epoch [5/25], Step [590/647], Loss: 0.0026
# Epoch [5/25], Step [600/647], Loss: 0.0060
# Epoch [5/25], Step [610/647], Loss: 0.0027
# Epoch [5/25], Step [620/647], Loss: 0.0034
# Epoch [5/25], Step [630/647], Loss: 0.0025
# Epoch [5/25], Step [640/647], Loss: 0.0032
# End of epoch
# Epoch [6/25], Step [10/647], Loss: 0.0014
# Epoch [6/25], Step [20/647], Loss: 0.0027
# Epoch [6/25], Step [30/647], Loss: 0.0027
# Epoch [6/25], Step [40/647], Loss: 0.0025
# Epoch [6/25], Step [50/647], Loss: 0.0015
# Epoch [6/25], Step [60/647], Loss: 0.0042
# Epoch [6/25], Step [70/647], Loss: 0.0035
# Epoch [6/25], Step [80/647], Loss: 0.0014
# Epoch [6/25], Step [90/647], Loss: 0.0051
# Epoch [6/25], Step [100/647], Loss: 0.0029
# Epoch [6/25], Step [110/647], Loss: 0.0031
# Epoch [6/25], Step [120/647], Loss: 0.0027
# Epoch [6/25], Step [130/647], Loss: 0.0034
# Epoch [6/25], Step [140/647], Loss: 0.0028
# Epoch [6/25], Step [150/647], Loss: 0.0032
# Epoch [6/25], Step [160/647], Loss: 0.0048
# Epoch [6/25], Step [170/647], Loss: 0.0020
# Epoch [6/25], Step [180/647], Loss: 0.0019
# Epoch [6/25], Step [190/647], Loss: 0.0036
# Epoch [6/25], Step [200/647], Loss: 0.0022
# Epoch [6/25], Step [210/647], Loss: 0.0013
# Epoch [6/25], Step [220/647], Loss: 0.0023
# Epoch [6/25], Step [230/647], Loss: 0.0040
# Epoch [6/25], Step [240/647], Loss: 0.0035
# Epoch [6/25], Step [250/647], Loss: 0.0040
# Epoch [6/25], Step [260/647], Loss: 0.0025
# Epoch [6/25], Step [270/647], Loss: 0.0026
# Epoch [6/25], Step [280/647], Loss: 0.0019
# Epoch [6/25], Step [290/647], Loss: 0.0021
# Epoch [6/25], Step [300/647], Loss: 0.0025
# Epoch [6/25], Step [310/647], Loss: 0.0012
# Epoch [6/25], Step [320/647], Loss: 0.0026
# Epoch [6/25], Step [330/647], Loss: 0.0020
# Epoch [6/25], Step [340/647], Loss: 0.0031
# Epoch [6/25], Step [350/647], Loss: 0.0044
# Epoch [6/25], Step [360/647], Loss: 0.0018
# Epoch [6/25], Step [370/647], Loss: 0.0029
# Epoch [6/25], Step [380/647], Loss: 0.0020
# Epoch [6/25], Step [390/647], Loss: 0.0032
# Epoch [6/25], Step [400/647], Loss: 0.0052
# Epoch [6/25], Step [410/647], Loss: 0.0020
# Epoch [6/25], Step [420/647], Loss: 0.0033
# Epoch [6/25], Step [430/647], Loss: 0.0035
# Epoch [6/25], Step [440/647], Loss: 0.0024
# Epoch [6/25], Step [450/647], Loss: 0.0016
# Epoch [6/25], Step [460/647], Loss: 0.0021
# Epoch [6/25], Step [470/647], Loss: 0.0020
# Epoch [6/25], Step [480/647], Loss: 0.0038
# Epoch [6/25], Step [490/647], Loss: 0.0025
# Epoch [6/25], Step [500/647], Loss: 0.0032
# Epoch [6/25], Step [510/647], Loss: 0.0022
# Epoch [6/25], Step [520/647], Loss: 0.0012
# Epoch [6/25], Step [530/647], Loss: 0.0021
# Epoch [6/25], Step [540/647], Loss: 0.0023
# Epoch [6/25], Step [550/647], Loss: 0.0020
# Epoch [6/25], Step [560/647], Loss: 0.0028
# Epoch [6/25], Step [570/647], Loss: 0.0025
# Epoch [6/25], Step [580/647], Loss: 0.0048
# Epoch [6/25], Step [590/647], Loss: 0.0011
# Epoch [6/25], Step [600/647], Loss: 0.0024
# Epoch [6/25], Step [610/647], Loss: 0.0016
# Epoch [6/25], Step [620/647], Loss: 0.0033
# Epoch [6/25], Step [630/647], Loss: 0.0019
# Epoch [6/25], Step [640/647], Loss: 0.0012
# End of epoch
# Score of  0.0017511160112917423 is the best yet. Saving model ...
# Epoch [7/25], Step [10/647], Loss: 0.0015
# Epoch [7/25], Step [20/647], Loss: 0.0035
# Epoch [7/25], Step [30/647], Loss: 0.0027
# Epoch [7/25], Step [40/647], Loss: 0.0018
# Epoch [7/25], Step [50/647], Loss: 0.0034
# Epoch [7/25], Step [60/647], Loss: 0.0011
# Epoch [7/25], Step [70/647], Loss: 0.0015
# Epoch [7/25], Step [80/647], Loss: 0.0021
# Epoch [7/25], Step [90/647], Loss: 0.0025
# Epoch [7/25], Step [100/647], Loss: 0.0024
# Epoch [7/25], Step [110/647], Loss: 0.0046
# Epoch [7/25], Step [120/647], Loss: 0.0034
# Epoch [7/25], Step [130/647], Loss: 0.0038
# Epoch [7/25], Step [140/647], Loss: 0.0017
# Epoch [7/25], Step [150/647], Loss: 0.0020
# Epoch [7/25], Step [160/647], Loss: 0.0019
# Epoch [7/25], Step [170/647], Loss: 0.0031
# Epoch [7/25], Step [180/647], Loss: 0.0020
# Epoch [7/25], Step [190/647], Loss: 0.0019
# Epoch [7/25], Step [200/647], Loss: 0.0017
# Epoch [7/25], Step [210/647], Loss: 0.0030
# Epoch [7/25], Step [220/647], Loss: 0.0035
# Epoch [7/25], Step [230/647], Loss: 0.0027
# Epoch [7/25], Step [240/647], Loss: 0.0014
# Epoch [7/25], Step [250/647], Loss: 0.0019
# Epoch [7/25], Step [260/647], Loss: 0.0013
# Epoch [7/25], Step [270/647], Loss: 0.0029
# Epoch [7/25], Step [280/647], Loss: 0.0010
# Epoch [7/25], Step [290/647], Loss: 0.0016
# Epoch [7/25], Step [300/647], Loss: 0.0024
# Epoch [7/25], Step [310/647], Loss: 0.0038
# Epoch [7/25], Step [320/647], Loss: 0.0040
# Epoch [7/25], Step [330/647], Loss: 0.0020
# Epoch [7/25], Step [340/647], Loss: 0.0014
# Epoch [7/25], Step [350/647], Loss: 0.0022
# Epoch [7/25], Step [360/647], Loss: 0.0019
# Epoch [7/25], Step [370/647], Loss: 0.0017
# Epoch [7/25], Step [380/647], Loss: 0.0043
# Epoch [7/25], Step [390/647], Loss: 0.0033
# Epoch [7/25], Step [400/647], Loss: 0.0015
# Epoch [7/25], Step [410/647], Loss: 0.0025
# Epoch [7/25], Step [420/647], Loss: 0.0016
# Epoch [7/25], Step [430/647], Loss: 0.0014
# Epoch [7/25], Step [440/647], Loss: 0.0032
# Epoch [7/25], Step [450/647], Loss: 0.0028
# Epoch [7/25], Step [460/647], Loss: 0.0026
# Epoch [7/25], Step [470/647], Loss: 0.0022
# Epoch [7/25], Step [480/647], Loss: 0.0019
# Epoch [7/25], Step [490/647], Loss: 0.0033
# Epoch [7/25], Step [500/647], Loss: 0.0019
# Epoch [7/25], Step [510/647], Loss: 0.0030
# Epoch [7/25], Step [520/647], Loss: 0.0021
# Epoch [7/25], Step [530/647], Loss: 0.0013
# Epoch [7/25], Step [540/647], Loss: 0.0023
# Epoch [7/25], Step [550/647], Loss: 0.0024
# Epoch [7/25], Step [560/647], Loss: 0.0024
# Epoch [7/25], Step [570/647], Loss: 0.0015
# Epoch [7/25], Step [580/647], Loss: 0.0019
# Epoch [7/25], Step [590/647], Loss: 0.0029
# Epoch [7/25], Step [600/647], Loss: 0.0019
# Epoch [7/25], Step [610/647], Loss: 0.0025
# Epoch [7/25], Step [620/647], Loss: 0.0024
# Epoch [7/25], Step [630/647], Loss: 0.0012
# Epoch [7/25], Step [640/647], Loss: 0.0028
# End of epoch
# Epoch [8/25], Step [10/647], Loss: 0.0049
# Epoch [8/25], Step [20/647], Loss: 0.0022
# Epoch [8/25], Step [30/647], Loss: 0.0040
# Epoch [8/25], Step [40/647], Loss: 0.0017
# Epoch [8/25], Step [50/647], Loss: 0.0019
# Epoch [8/25], Step [60/647], Loss: 0.0019
# Epoch [8/25], Step [70/647], Loss: 0.0025
# Epoch [8/25], Step [80/647], Loss: 0.0027
# Epoch [8/25], Step [90/647], Loss: 0.0022
# Epoch [8/25], Step [100/647], Loss: 0.0017
# Epoch [8/25], Step [110/647], Loss: 0.0035
# Epoch [8/25], Step [120/647], Loss: 0.0019
# Epoch [8/25], Step [130/647], Loss: 0.0013
# Epoch [8/25], Step [140/647], Loss: 0.0013
# Epoch [8/25], Step [150/647], Loss: 0.0018
# Epoch [8/25], Step [160/647], Loss: 0.0031
# Epoch [8/25], Step [170/647], Loss: 0.0022
# Epoch [8/25], Step [180/647], Loss: 0.0024
# Epoch [8/25], Step [190/647], Loss: 0.0029
# Epoch [8/25], Step [200/647], Loss: 0.0029
# Epoch [8/25], Step [210/647], Loss: 0.0021
# Epoch [8/25], Step [220/647], Loss: 0.0014
# Epoch [8/25], Step [230/647], Loss: 0.0026
# Epoch [8/25], Step [240/647], Loss: 0.0026
# Epoch [8/25], Step [250/647], Loss: 0.0026
# Epoch [8/25], Step [260/647], Loss: 0.0023
# Epoch [8/25], Step [270/647], Loss: 0.0017
# Epoch [8/25], Step [280/647], Loss: 0.0011
# Epoch [8/25], Step [290/647], Loss: 0.0017
# Epoch [8/25], Step [300/647], Loss: 0.0024
# Epoch [8/25], Step [310/647], Loss: 0.0023
# Epoch [8/25], Step [320/647], Loss: 0.0024
# Epoch [8/25], Step [330/647], Loss: 0.0030
# Epoch [8/25], Step [340/647], Loss: 0.0027
# Epoch [8/25], Step [350/647], Loss: 0.0026
# Epoch [8/25], Step [360/647], Loss: 0.0026
# Epoch [8/25], Step [370/647], Loss: 0.0032
# Epoch [8/25], Step [380/647], Loss: 0.0016
# Epoch [8/25], Step [390/647], Loss: 0.0016
# Epoch [8/25], Step [400/647], Loss: 0.0026
# Epoch [8/25], Step [410/647], Loss: 0.0031
# Epoch [8/25], Step [420/647], Loss: 0.0021
# Epoch [8/25], Step [430/647], Loss: 0.0037
# Epoch [8/25], Step [440/647], Loss: 0.0014
# Epoch [8/25], Step [450/647], Loss: 0.0041
# Epoch [8/25], Step [460/647], Loss: 0.0041
# Epoch [8/25], Step [470/647], Loss: 0.0025
# Epoch [8/25], Step [480/647], Loss: 0.0017
# Epoch [8/25], Step [490/647], Loss: 0.0019
# Epoch [8/25], Step [500/647], Loss: 0.0026
# Epoch [8/25], Step [510/647], Loss: 0.0022
# Epoch [8/25], Step [520/647], Loss: 0.0021
# Epoch [8/25], Step [530/647], Loss: 0.0018
# Epoch [8/25], Step [540/647], Loss: 0.0032
# Epoch [8/25], Step [550/647], Loss: 0.0015
# Epoch [8/25], Step [560/647], Loss: 0.0022
# Epoch [8/25], Step [570/647], Loss: 0.0023
# Epoch [8/25], Step [580/647], Loss: 0.0014
# Epoch [8/25], Step [590/647], Loss: 0.0016
# Epoch [8/25], Step [600/647], Loss: 0.0016
# Epoch [8/25], Step [610/647], Loss: 0.0020
# Epoch [8/25], Step [620/647], Loss: 0.0024
# Epoch [8/25], Step [630/647], Loss: 0.0027
# Epoch [8/25], Step [640/647], Loss: 0.0028
# End of epoch
# Epoch [9/25], Step [10/647], Loss: 0.0034
# Epoch [9/25], Step [20/647], Loss: 0.0029
# Epoch [9/25], Step [30/647], Loss: 0.0029
# Epoch [9/25], Step [40/647], Loss: 0.0043
# Epoch [9/25], Step [50/647], Loss: 0.0029
# Epoch [9/25], Step [60/647], Loss: 0.0025
# Epoch [9/25], Step [70/647], Loss: 0.0023
# Epoch [9/25], Step [80/647], Loss: 0.0026
# Epoch [9/25], Step [90/647], Loss: 0.0019
# Epoch [9/25], Step [100/647], Loss: 0.0019
# Epoch [9/25], Step [110/647], Loss: 0.0035
# Epoch [9/25], Step [120/647], Loss: 0.0025
# Epoch [9/25], Step [130/647], Loss: 0.0036
# Epoch [9/25], Step [140/647], Loss: 0.0013
# Epoch [9/25], Step [150/647], Loss: 0.0018
# Epoch [9/25], Step [160/647], Loss: 0.0042
# Epoch [9/25], Step [170/647], Loss: 0.0019
# Epoch [9/25], Step [180/647], Loss: 0.0025
# Epoch [9/25], Step [190/647], Loss: 0.0020
# Epoch [9/25], Step [200/647], Loss: 0.0017
# Epoch [9/25], Step [210/647], Loss: 0.0033
# Epoch [9/25], Step [220/647], Loss: 0.0017
# Epoch [9/25], Step [230/647], Loss: 0.0015
# Epoch [9/25], Step [240/647], Loss: 0.0022
# Epoch [9/25], Step [250/647], Loss: 0.0021
# Epoch [9/25], Step [260/647], Loss: 0.0023
# Epoch [9/25], Step [270/647], Loss: 0.0024
# Epoch [9/25], Step [280/647], Loss: 0.0020
# Epoch [9/25], Step [290/647], Loss: 0.0009
# Epoch [9/25], Step [300/647], Loss: 0.0018
# Epoch [9/25], Step [310/647], Loss: 0.0020
# Epoch [9/25], Step [320/647], Loss: 0.0030
# Epoch [9/25], Step [330/647], Loss: 0.0022
# Epoch [9/25], Step [340/647], Loss: 0.0022
# Epoch [9/25], Step [350/647], Loss: 0.0012
# Epoch [9/25], Step [360/647], Loss: 0.0015
# Epoch [9/25], Step [370/647], Loss: 0.0020
# Epoch [9/25], Step [380/647], Loss: 0.0018
# Epoch [9/25], Step [390/647], Loss: 0.0028
# Epoch [9/25], Step [400/647], Loss: 0.0038
# Epoch [9/25], Step [410/647], Loss: 0.0021
# Epoch [9/25], Step [420/647], Loss: 0.0014
# Epoch [9/25], Step [430/647], Loss: 0.0013
# Epoch [9/25], Step [440/647], Loss: 0.0019
# Epoch [9/25], Step [450/647], Loss: 0.0032
# Epoch [9/25], Step [460/647], Loss: 0.0024
# Epoch [9/25], Step [470/647], Loss: 0.0015
# Epoch [9/25], Step [480/647], Loss: 0.0035
# Epoch [9/25], Step [490/647], Loss: 0.0021
# Epoch [9/25], Step [500/647], Loss: 0.0014
# Epoch [9/25], Step [510/647], Loss: 0.0025
# Epoch [9/25], Step [520/647], Loss: 0.0021
# Epoch [9/25], Step [530/647], Loss: 0.0025
# Epoch [9/25], Step [540/647], Loss: 0.0017
# Epoch [9/25], Step [550/647], Loss: 0.0030
# Epoch [9/25], Step [560/647], Loss: 0.0029
# Epoch [9/25], Step [570/647], Loss: 0.0026
# Epoch [9/25], Step [580/647], Loss: 0.0017
# Epoch [9/25], Step [590/647], Loss: 0.0011
# Epoch [9/25], Step [600/647], Loss: 0.0012
# Epoch [9/25], Step [610/647], Loss: 0.0010
# Epoch [9/25], Step [620/647], Loss: 0.0026
# Epoch [9/25], Step [630/647], Loss: 0.0018
# Epoch [9/25], Step [640/647], Loss: 0.0019
# End of epoch
# Epoch [10/25], Step [10/647], Loss: 0.0017
# Epoch [10/25], Step [20/647], Loss: 0.0017
# Epoch [10/25], Step [30/647], Loss: 0.0032
# Epoch [10/25], Step [40/647], Loss: 0.0020
# Epoch [10/25], Step [50/647], Loss: 0.0029
# Epoch [10/25], Step [60/647], Loss: 0.0023
# Epoch [10/25], Step [70/647], Loss: 0.0032
# Epoch [10/25], Step [80/647], Loss: 0.0009
# Epoch [10/25], Step [90/647], Loss: 0.0025
# Epoch [10/25], Step [100/647], Loss: 0.0017
# Epoch [10/25], Step [110/647], Loss: 0.0016
# Epoch [10/25], Step [120/647], Loss: 0.0036
# Epoch [10/25], Step [130/647], Loss: 0.0013
# Epoch [10/25], Step [140/647], Loss: 0.0020
# Epoch [10/25], Step [150/647], Loss: 0.0019
# Epoch [10/25], Step [160/647], Loss: 0.0021
# Epoch [10/25], Step [170/647], Loss: 0.0018
# Epoch [10/25], Step [180/647], Loss: 0.0012
# Epoch [10/25], Step [190/647], Loss: 0.0016
# Epoch [10/25], Step [200/647], Loss: 0.0022
# Epoch [10/25], Step [210/647], Loss: 0.0019
# Epoch [10/25], Step [220/647], Loss: 0.0020
# Epoch [10/25], Step [230/647], Loss: 0.0020
# Epoch [10/25], Step [240/647], Loss: 0.0029
# Epoch [10/25], Step [250/647], Loss: 0.0017
# Epoch [10/25], Step [260/647], Loss: 0.0016
# Epoch [10/25], Step [270/647], Loss: 0.0019
# Epoch [10/25], Step [280/647], Loss: 0.0022
# Epoch [10/25], Step [290/647], Loss: 0.0025
# Epoch [10/25], Step [300/647], Loss: 0.0042
# Epoch [10/25], Step [310/647], Loss: 0.0012
# Epoch [10/25], Step [320/647], Loss: 0.0031
# Epoch [10/25], Step [330/647], Loss: 0.0016
# Epoch [10/25], Step [340/647], Loss: 0.0021
# Epoch [10/25], Step [350/647], Loss: 0.0015
# Epoch [10/25], Step [360/647], Loss: 0.0037
# Epoch [10/25], Step [370/647], Loss: 0.0016
# Epoch [10/25], Step [380/647], Loss: 0.0010
# Epoch [10/25], Step [390/647], Loss: 0.0015
# Epoch [10/25], Step [400/647], Loss: 0.0025
# Epoch [10/25], Step [410/647], Loss: 0.0032
# Epoch [10/25], Step [420/647], Loss: 0.0023
# Epoch [10/25], Step [430/647], Loss: 0.0020
# Epoch [10/25], Step [440/647], Loss: 0.0021
# Epoch [10/25], Step [450/647], Loss: 0.0017
# Epoch [10/25], Step [460/647], Loss: 0.0015
# Epoch [10/25], Step [470/647], Loss: 0.0027
# Epoch [10/25], Step [480/647], Loss: 0.0020
# Epoch [10/25], Step [490/647], Loss: 0.0011
# Epoch [10/25], Step [500/647], Loss: 0.0046
# Epoch [10/25], Step [510/647], Loss: 0.0026
# Epoch [10/25], Step [520/647], Loss: 0.0018
# Epoch [10/25], Step [530/647], Loss: 0.0018
# Epoch [10/25], Step [540/647], Loss: 0.0031
# Epoch [10/25], Step [550/647], Loss: 0.0014
# Epoch [10/25], Step [560/647], Loss: 0.0013
# Epoch [10/25], Step [570/647], Loss: 0.0052
# Epoch [10/25], Step [580/647], Loss: 0.0018
# Epoch [10/25], Step [590/647], Loss: 0.0021
# Epoch [10/25], Step [600/647], Loss: 0.0030
# Epoch [10/25], Step [610/647], Loss: 0.0014
# Epoch [10/25], Step [620/647], Loss: 0.0027
# Epoch [10/25], Step [630/647], Loss: 0.0024
# Epoch [10/25], Step [640/647], Loss: 0.0020
# End of epoch
# Epoch [11/25], Step [10/647], Loss: 0.0022
# Epoch [11/25], Step [20/647], Loss: 0.0017
# Epoch [11/25], Step [30/647], Loss: 0.0029
# Epoch [11/25], Step [40/647], Loss: 0.0010
# Epoch [11/25], Step [50/647], Loss: 0.0017
# Epoch [11/25], Step [60/647], Loss: 0.0015
# Epoch [11/25], Step [70/647], Loss: 0.0027
# Epoch [11/25], Step [80/647], Loss: 0.0010
# Epoch [11/25], Step [90/647], Loss: 0.0027
# Epoch [11/25], Step [100/647], Loss: 0.0018
# Epoch [11/25], Step [110/647], Loss: 0.0030
# Epoch [11/25], Step [120/647], Loss: 0.0016
# Epoch [11/25], Step [130/647], Loss: 0.0014
# Epoch [11/25], Step [140/647], Loss: 0.0025
# Epoch [11/25], Step [150/647], Loss: 0.0033
# Epoch [11/25], Step [160/647], Loss: 0.0017
# Epoch [11/25], Step [170/647], Loss: 0.0011
# Epoch [11/25], Step [180/647], Loss: 0.0026
# Epoch [11/25], Step [190/647], Loss: 0.0014
# Epoch [11/25], Step [200/647], Loss: 0.0016
# Epoch [11/25], Step [210/647], Loss: 0.0009
# Epoch [11/25], Step [220/647], Loss: 0.0016
# Epoch [11/25], Step [230/647], Loss: 0.0026
# Epoch [11/25], Step [240/647], Loss: 0.0016
# Epoch [11/25], Step [250/647], Loss: 0.0027
# Epoch [11/25], Step [260/647], Loss: 0.0017
# Epoch [11/25], Step [270/647], Loss: 0.0011
# Epoch [11/25], Step [280/647], Loss: 0.0019
# Epoch [11/25], Step [290/647], Loss: 0.0025
# Epoch [11/25], Step [300/647], Loss: 0.0025
# Epoch [11/25], Step [310/647], Loss: 0.0013
# Epoch [11/25], Step [320/647], Loss: 0.0016
# Epoch [11/25], Step [330/647], Loss: 0.0025
# Epoch [11/25], Step [340/647], Loss: 0.0017
# Epoch [11/25], Step [350/647], Loss: 0.0025
# Epoch [11/25], Step [360/647], Loss: 0.0018
# Epoch [11/25], Step [370/647], Loss: 0.0028
# Epoch [11/25], Step [380/647], Loss: 0.0016
# Epoch [11/25], Step [390/647], Loss: 0.0020
# Epoch [11/25], Step [400/647], Loss: 0.0023
# Epoch [11/25], Step [410/647], Loss: 0.0013
# Epoch [11/25], Step [420/647], Loss: 0.0024
# Epoch [11/25], Step [430/647], Loss: 0.0014
# Epoch [11/25], Step [440/647], Loss: 0.0022
# Epoch [11/25], Step [450/647], Loss: 0.0017
# Epoch [11/25], Step [460/647], Loss: 0.0013
# Epoch [11/25], Step [470/647], Loss: 0.0013
# Epoch [11/25], Step [480/647], Loss: 0.0022
# Epoch [11/25], Step [490/647], Loss: 0.0026
# Epoch [11/25], Step [500/647], Loss: 0.0021
# Epoch [11/25], Step [510/647], Loss: 0.0024
# Epoch [11/25], Step [520/647], Loss: 0.0023
# Epoch [11/25], Step [530/647], Loss: 0.0028
# Epoch [11/25], Step [540/647], Loss: 0.0027
# Epoch [11/25], Step [550/647], Loss: 0.0024
# Epoch [11/25], Step [560/647], Loss: 0.0010
# Epoch [11/25], Step [570/647], Loss: 0.0014
# Epoch [11/25], Step [580/647], Loss: 0.0013
# Epoch [11/25], Step [590/647], Loss: 0.0013
# Epoch [11/25], Step [600/647], Loss: 0.0019
# Epoch [11/25], Step [610/647], Loss: 0.0013
# Epoch [11/25], Step [620/647], Loss: 0.0020
# Epoch [11/25], Step [630/647], Loss: 0.0038
# Epoch [11/25], Step [640/647], Loss: 0.0023
# End of epoch
# Epoch [12/25], Step [10/647], Loss: 0.0015
# Epoch [12/25], Step [20/647], Loss: 0.0012
# Epoch [12/25], Step [30/647], Loss: 0.0013
# Epoch [12/25], Step [40/647], Loss: 0.0021
# Epoch [12/25], Step [50/647], Loss: 0.0019
# Epoch [12/25], Step [60/647], Loss: 0.0015
# Epoch [12/25], Step [70/647], Loss: 0.0012
# Epoch [12/25], Step [80/647], Loss: 0.0025
# Epoch [12/25], Step [90/647], Loss: 0.0013
# Epoch [12/25], Step [100/647], Loss: 0.0016
# Epoch [12/25], Step [110/647], Loss: 0.0009
# Epoch [12/25], Step [120/647], Loss: 0.0020
# Epoch [12/25], Step [130/647], Loss: 0.0026
# Epoch [12/25], Step [140/647], Loss: 0.0010
# Epoch [12/25], Step [150/647], Loss: 0.0023
# Epoch [12/25], Step [160/647], Loss: 0.0033
# Epoch [12/25], Step [170/647], Loss: 0.0033
# Epoch [12/25], Step [180/647], Loss: 0.0012
# Epoch [12/25], Step [190/647], Loss: 0.0013
# Epoch [12/25], Step [200/647], Loss: 0.0020
# Epoch [12/25], Step [210/647], Loss: 0.0019
# Epoch [12/25], Step [220/647], Loss: 0.0012
# Epoch [12/25], Step [230/647], Loss: 0.0036
# Epoch [12/25], Step [240/647], Loss: 0.0012
# Epoch [12/25], Step [250/647], Loss: 0.0012
# Epoch [12/25], Step [260/647], Loss: 0.0018
# Epoch [12/25], Step [270/647], Loss: 0.0017
# Epoch [12/25], Step [280/647], Loss: 0.0029
# Epoch [12/25], Step [290/647], Loss: 0.0025
# Epoch [12/25], Step [300/647], Loss: 0.0022
# Epoch [12/25], Step [310/647], Loss: 0.0019
# Epoch [12/25], Step [320/647], Loss: 0.0019
# Epoch [12/25], Step [330/647], Loss: 0.0013
# Epoch [12/25], Step [340/647], Loss: 0.0033
# Epoch [12/25], Step [350/647], Loss: 0.0028
# Epoch [12/25], Step [360/647], Loss: 0.0028
# Epoch [12/25], Step [370/647], Loss: 0.0034
# Epoch [12/25], Step [380/647], Loss: 0.0020
# Epoch [12/25], Step [390/647], Loss: 0.0026
# Epoch [12/25], Step [400/647], Loss: 0.0017
# Epoch [12/25], Step [410/647], Loss: 0.0018
# Epoch [12/25], Step [420/647], Loss: 0.0020
# Epoch [12/25], Step [430/647], Loss: 0.0033
# Epoch [12/25], Step [440/647], Loss: 0.0033
# Epoch [12/25], Step [450/647], Loss: 0.0026
# Epoch [12/25], Step [460/647], Loss: 0.0015
# Epoch [12/25], Step [470/647], Loss: 0.0022
# Epoch [12/25], Step [480/647], Loss: 0.0025
# Epoch [12/25], Step [490/647], Loss: 0.0025
# Epoch [12/25], Step [500/647], Loss: 0.0010
# Epoch [12/25], Step [510/647], Loss: 0.0031
# Epoch [12/25], Step [520/647], Loss: 0.0030
# Epoch [12/25], Step [530/647], Loss: 0.0023
# Epoch [12/25], Step [540/647], Loss: 0.0009
# Epoch [12/25], Step [550/647], Loss: 0.0015
# Epoch [12/25], Step [560/647], Loss: 0.0020
# Epoch [12/25], Step [570/647], Loss: 0.0047
# Epoch [12/25], Step [580/647], Loss: 0.0026
# Epoch [12/25], Step [590/647], Loss: 0.0022
# Epoch [12/25], Step [600/647], Loss: 0.0023
# Epoch [12/25], Step [610/647], Loss: 0.0031
# Epoch [12/25], Step [620/647], Loss: 0.0022
# Epoch [12/25], Step [630/647], Loss: 0.0033
# Epoch [12/25], Step [640/647], Loss: 0.0011
# End of epoch
# Epoch [13/25], Step [10/647], Loss: 0.0016
# Epoch [13/25], Step [20/647], Loss: 0.0020
# Epoch [13/25], Step [30/647], Loss: 0.0017
# Epoch [13/25], Step [40/647], Loss: 0.0024
# Epoch [13/25], Step [50/647], Loss: 0.0018
# Epoch [13/25], Step [60/647], Loss: 0.0022
# Epoch [13/25], Step [70/647], Loss: 0.0028
# Epoch [13/25], Step [80/647], Loss: 0.0015
# Epoch [13/25], Step [90/647], Loss: 0.0025
# Epoch [13/25], Step [100/647], Loss: 0.0014
# Epoch [13/25], Step [110/647], Loss: 0.0014
# Epoch [13/25], Step [120/647], Loss: 0.0012
# Epoch [13/25], Step [130/647], Loss: 0.0011
# Epoch [13/25], Step [140/647], Loss: 0.0025
# Epoch [13/25], Step [150/647], Loss: 0.0019
# Epoch [13/25], Step [160/647], Loss: 0.0016
# Epoch [13/25], Step [170/647], Loss: 0.0014
# Epoch [13/25], Step [180/647], Loss: 0.0030
# Epoch [13/25], Step [190/647], Loss: 0.0021
# Epoch [13/25], Step [200/647], Loss: 0.0031
# Epoch [13/25], Step [210/647], Loss: 0.0013
# Epoch [13/25], Step [220/647], Loss: 0.0014
# Epoch [13/25], Step [230/647], Loss: 0.0025
# Epoch [13/25], Step [240/647], Loss: 0.0010
# Epoch [13/25], Step [250/647], Loss: 0.0023
# Epoch [13/25], Step [260/647], Loss: 0.0021
# Epoch [13/25], Step [270/647], Loss: 0.0009
# Epoch [13/25], Step [280/647], Loss: 0.0020
# Epoch [13/25], Step [290/647], Loss: 0.0023
# Epoch [13/25], Step [300/647], Loss: 0.0040
# Epoch [13/25], Step [310/647], Loss: 0.0026
# Epoch [13/25], Step [320/647], Loss: 0.0016
# Epoch [13/25], Step [330/647], Loss: 0.0015
# Epoch [13/25], Step [340/647], Loss: 0.0023
# Epoch [13/25], Step [350/647], Loss: 0.0036
# Epoch [13/25], Step [360/647], Loss: 0.0022
# Epoch [13/25], Step [370/647], Loss: 0.0025
# Epoch [13/25], Step [380/647], Loss: 0.0015
# Epoch [13/25], Step [390/647], Loss: 0.0013
# Epoch [13/25], Step [400/647], Loss: 0.0012
# Epoch [13/25], Step [410/647], Loss: 0.0017
# Epoch [13/25], Step [420/647], Loss: 0.0015
# Epoch [13/25], Step [430/647], Loss: 0.0011
# Epoch [13/25], Step [440/647], Loss: 0.0021
# Epoch [13/25], Step [450/647], Loss: 0.0035
# Epoch [13/25], Step [460/647], Loss: 0.0017
# Epoch [13/25], Step [470/647], Loss: 0.0027
# Epoch [13/25], Step [480/647], Loss: 0.0011
# Epoch [13/25], Step [490/647], Loss: 0.0035
# Epoch [13/25], Step [500/647], Loss: 0.0019
# Epoch [13/25], Step [510/647], Loss: 0.0022
# Epoch [13/25], Step [520/647], Loss: 0.0044
# Epoch [13/25], Step [530/647], Loss: 0.0026
# Epoch [13/25], Step [540/647], Loss: 0.0047
# Epoch [13/25], Step [550/647], Loss: 0.0017
# Epoch [13/25], Step [560/647], Loss: 0.0067
# Epoch [13/25], Step [570/647], Loss: 0.0015
# Epoch [13/25], Step [580/647], Loss: 0.0019
# Epoch [13/25], Step [590/647], Loss: 0.0024
# Epoch [13/25], Step [600/647], Loss: 0.0010
# Epoch [13/25], Step [610/647], Loss: 0.0020
# Epoch [13/25], Step [620/647], Loss: 0.0018
# Epoch [13/25], Step [630/647], Loss: 0.0030
# Epoch [13/25], Step [640/647], Loss: 0.0032
# End of epoch
# Epoch [14/25], Step [10/647], Loss: 0.0015
# Epoch [14/25], Step [20/647], Loss: 0.0034
# Epoch [14/25], Step [30/647], Loss: 0.0018
# Epoch [14/25], Step [40/647], Loss: 0.0014
# Epoch [14/25], Step [50/647], Loss: 0.0007
# Epoch [14/25], Step [60/647], Loss: 0.0011
# Epoch [14/25], Step [70/647], Loss: 0.0019
# Epoch [14/25], Step [80/647], Loss: 0.0028
# Epoch [14/25], Step [90/647], Loss: 0.0031
# Epoch [14/25], Step [100/647], Loss: 0.0019
# Epoch [14/25], Step [110/647], Loss: 0.0027
# Epoch [14/25], Step [120/647], Loss: 0.0012
# Epoch [14/25], Step [130/647], Loss: 0.0013
# Epoch [14/25], Step [140/647], Loss: 0.0022
# Epoch [14/25], Step [150/647], Loss: 0.0016
# Epoch [14/25], Step [160/647], Loss: 0.0026
# Epoch [14/25], Step [170/647], Loss: 0.0025
# Epoch [14/25], Step [180/647], Loss: 0.0013
# Epoch [14/25], Step [190/647], Loss: 0.0036
# Epoch [14/25], Step [200/647], Loss: 0.0014
# Epoch [14/25], Step [210/647], Loss: 0.0018
# Epoch [14/25], Step [220/647], Loss: 0.0025
# Epoch [14/25], Step [230/647], Loss: 0.0022
# Epoch [14/25], Step [240/647], Loss: 0.0016
# Epoch [14/25], Step [250/647], Loss: 0.0019
# Epoch [14/25], Step [260/647], Loss: 0.0021
# Epoch [14/25], Step [270/647], Loss: 0.0020
# Epoch [14/25], Step [280/647], Loss: 0.0022
# Epoch [14/25], Step [290/647], Loss: 0.0008
# Epoch [14/25], Step [300/647], Loss: 0.0015
# Epoch [14/25], Step [310/647], Loss: 0.0018
# Epoch [14/25], Step [320/647], Loss: 0.0012
# Epoch [14/25], Step [330/647], Loss: 0.0027
# Epoch [14/25], Step [340/647], Loss: 0.0009
# Epoch [14/25], Step [350/647], Loss: 0.0016
# Epoch [14/25], Step [360/647], Loss: 0.0025
# Epoch [14/25], Step [370/647], Loss: 0.0016
# Epoch [14/25], Step [380/647], Loss: 0.0024
# Epoch [14/25], Step [390/647], Loss: 0.0018
# Epoch [14/25], Step [400/647], Loss: 0.0016
# Epoch [14/25], Step [410/647], Loss: 0.0033
# Epoch [14/25], Step [420/647], Loss: 0.0023
# Epoch [14/25], Step [430/647], Loss: 0.0032
# Epoch [14/25], Step [440/647], Loss: 0.0022
# Epoch [14/25], Step [450/647], Loss: 0.0018
# Epoch [14/25], Step [460/647], Loss: 0.0008
# Epoch [14/25], Step [470/647], Loss: 0.0026
# Epoch [14/25], Step [480/647], Loss: 0.0018
# Epoch [14/25], Step [490/647], Loss: 0.0017
# Epoch [14/25], Step [500/647], Loss: 0.0018
# Epoch [14/25], Step [510/647], Loss: 0.0015
# Epoch [14/25], Step [520/647], Loss: 0.0016
# Epoch [14/25], Step [530/647], Loss: 0.0015
# Epoch [14/25], Step [540/647], Loss: 0.0023
# Epoch [14/25], Step [550/647], Loss: 0.0010
# Epoch [14/25], Step [560/647], Loss: 0.0021
# Epoch [14/25], Step [570/647], Loss: 0.0018
# Epoch [14/25], Step [580/647], Loss: 0.0017
# Epoch [14/25], Step [590/647], Loss: 0.0013
# Epoch [14/25], Step [600/647], Loss: 0.0023
# Epoch [14/25], Step [610/647], Loss: 0.0018
# Epoch [14/25], Step [620/647], Loss: 0.0013
# Epoch [14/25], Step [630/647], Loss: 0.0031
# Epoch [14/25], Step [640/647], Loss: 0.0016
# End of epoch
# Epoch [15/25], Step [10/647], Loss: 0.0015
# Epoch [15/25], Step [20/647], Loss: 0.0015
# Epoch [15/25], Step [30/647], Loss: 0.0007
# Epoch [15/25], Step [40/647], Loss: 0.0020
# Epoch [15/25], Step [50/647], Loss: 0.0022
# Epoch [15/25], Step [60/647], Loss: 0.0016
# Epoch [15/25], Step [70/647], Loss: 0.0023
# Epoch [15/25], Step [80/647], Loss: 0.0026
# Epoch [15/25], Step [90/647], Loss: 0.0028
# Epoch [15/25], Step [100/647], Loss: 0.0019
# Epoch [15/25], Step [110/647], Loss: 0.0016
# Epoch [15/25], Step [120/647], Loss: 0.0018
# Epoch [15/25], Step [130/647], Loss: 0.0016
# Epoch [15/25], Step [140/647], Loss: 0.0011
# Epoch [15/25], Step [150/647], Loss: 0.0016
# Epoch [15/25], Step [160/647], Loss: 0.0016
# Epoch [15/25], Step [170/647], Loss: 0.0023
# Epoch [15/25], Step [180/647], Loss: 0.0015
# Epoch [15/25], Step [190/647], Loss: 0.0024
# Epoch [15/25], Step [200/647], Loss: 0.0012
# Epoch [15/25], Step [210/647], Loss: 0.0032
# Epoch [15/25], Step [220/647], Loss: 0.0015
# Epoch [15/25], Step [230/647], Loss: 0.0010
# Epoch [15/25], Step [240/647], Loss: 0.0029
# Epoch [15/25], Step [250/647], Loss: 0.0018
# Epoch [15/25], Step [260/647], Loss: 0.0020
# Epoch [15/25], Step [270/647], Loss: 0.0012
# Epoch [15/25], Step [280/647], Loss: 0.0020
# Epoch [15/25], Step [290/647], Loss: 0.0024
# Epoch [15/25], Step [300/647], Loss: 0.0034
# Epoch [15/25], Step [310/647], Loss: 0.0023
# Epoch [15/25], Step [320/647], Loss: 0.0028
# Epoch [15/25], Step [330/647], Loss: 0.0035
# Epoch [15/25], Step [340/647], Loss: 0.0016
# Epoch [15/25], Step [350/647], Loss: 0.0025
# Epoch [15/25], Step [360/647], Loss: 0.0017
# Epoch [15/25], Step [370/647], Loss: 0.0030
# Epoch [15/25], Step [380/647], Loss: 0.0018
# Epoch [15/25], Step [390/647], Loss: 0.0023
# Epoch [15/25], Step [400/647], Loss: 0.0018
# Epoch [15/25], Step [410/647], Loss: 0.0026
# Epoch [15/25], Step [420/647], Loss: 0.0017
# Epoch [15/25], Step [430/647], Loss: 0.0010
# Epoch [15/25], Step [440/647], Loss: 0.0016
# Epoch [15/25], Step [450/647], Loss: 0.0018
# Epoch [15/25], Step [460/647], Loss: 0.0027
# Epoch [15/25], Step [470/647], Loss: 0.0018
# Epoch [15/25], Step [480/647], Loss: 0.0035
# Epoch [15/25], Step [490/647], Loss: 0.0010
# Epoch [15/25], Step [500/647], Loss: 0.0037
# Epoch [15/25], Step [510/647], Loss: 0.0045
# Epoch [15/25], Step [520/647], Loss: 0.0030
# Epoch [15/25], Step [530/647], Loss: 0.0028
# Epoch [15/25], Step [540/647], Loss: 0.0018
# Epoch [15/25], Step [550/647], Loss: 0.0019
# Epoch [15/25], Step [560/647], Loss: 0.0018
# Epoch [15/25], Step [570/647], Loss: 0.0018
# Epoch [15/25], Step [580/647], Loss: 0.0014
# Epoch [15/25], Step [590/647], Loss: 0.0033
# Epoch [15/25], Step [600/647], Loss: 0.0023
# Epoch [15/25], Step [610/647], Loss: 0.0031
# Epoch [15/25], Step [620/647], Loss: 0.0018
# Epoch [15/25], Step [630/647], Loss: 0.0014
# Epoch [15/25], Step [640/647], Loss: 0.0017
# End of epoch
# Epoch [16/25], Step [10/647], Loss: 0.0017
# Epoch [16/25], Step [20/647], Loss: 0.0019
# Epoch [16/25], Step [30/647], Loss: 0.0031
# Epoch [16/25], Step [40/647], Loss: 0.0014
# Epoch [16/25], Step [50/647], Loss: 0.0019
# Epoch [16/25], Step [60/647], Loss: 0.0015
# Epoch [16/25], Step [70/647], Loss: 0.0016
# Epoch [16/25], Step [80/647], Loss: 0.0016
# Epoch [16/25], Step [90/647], Loss: 0.0025
# Epoch [16/25], Step [100/647], Loss: 0.0012
# Epoch [16/25], Step [110/647], Loss: 0.0013
# Epoch [16/25], Step [120/647], Loss: 0.0026
# Epoch [16/25], Step [130/647], Loss: 0.0014
# Epoch [16/25], Step [140/647], Loss: 0.0012
# Epoch [16/25], Step [150/647], Loss: 0.0012
# Epoch [16/25], Step [160/647], Loss: 0.0010
# Epoch [16/25], Step [170/647], Loss: 0.0026
# Epoch [16/25], Step [180/647], Loss: 0.0018
# Epoch [16/25], Step [190/647], Loss: 0.0031
# Epoch [16/25], Step [200/647], Loss: 0.0014
# Epoch [16/25], Step [210/647], Loss: 0.0022
# Epoch [16/25], Step [220/647], Loss: 0.0028
# Epoch [16/25], Step [230/647], Loss: 0.0022
# Epoch [16/25], Step [240/647], Loss: 0.0031
# Epoch [16/25], Step [250/647], Loss: 0.0022
# Epoch [16/25], Step [260/647], Loss: 0.0011
# Epoch [16/25], Step [270/647], Loss: 0.0021
# Epoch [16/25], Step [280/647], Loss: 0.0025
# Epoch [16/25], Step [290/647], Loss: 0.0019
# Epoch [16/25], Step [300/647], Loss: 0.0022
# Epoch [16/25], Step [310/647], Loss: 0.0013
# Epoch [16/25], Step [320/647], Loss: 0.0015
# Epoch [16/25], Step [330/647], Loss: 0.0010
# Epoch [16/25], Step [340/647], Loss: 0.0018
# Epoch [16/25], Step [350/647], Loss: 0.0021
# Epoch [16/25], Step [360/647], Loss: 0.0015
# Epoch [16/25], Step [370/647], Loss: 0.0040
# Epoch [16/25], Step [380/647], Loss: 0.0024
# Epoch [16/25], Step [390/647], Loss: 0.0012
# Epoch [16/25], Step [400/647], Loss: 0.0018
# Epoch [16/25], Step [410/647], Loss: 0.0028
# Epoch [16/25], Step [420/647], Loss: 0.0015
# Epoch [16/25], Step [430/647], Loss: 0.0033
# Epoch [16/25], Step [440/647], Loss: 0.0018
# Epoch [16/25], Step [450/647], Loss: 0.0014
# Epoch [16/25], Step [460/647], Loss: 0.0011
# Epoch [16/25], Step [470/647], Loss: 0.0015
# Epoch [16/25], Step [480/647], Loss: 0.0019
# Epoch [16/25], Step [490/647], Loss: 0.0020
# Epoch [16/25], Step [500/647], Loss: 0.0035
# Epoch [16/25], Step [510/647], Loss: 0.0018
# Epoch [16/25], Step [520/647], Loss: 0.0020
# Epoch [16/25], Step [530/647], Loss: 0.0024
# Epoch [16/25], Step [540/647], Loss: 0.0045
# Epoch [16/25], Step [550/647], Loss: 0.0016
# Epoch [16/25], Step [560/647], Loss: 0.0020
# Epoch [16/25], Step [570/647], Loss: 0.0019
# Epoch [16/25], Step [580/647], Loss: 0.0026
# Epoch [16/25], Step [590/647], Loss: 0.0022
# Epoch [16/25], Step [600/647], Loss: 0.0020
# Epoch [16/25], Step [610/647], Loss: 0.0017
# Epoch [16/25], Step [620/647], Loss: 0.0013
# Epoch [16/25], Step [630/647], Loss: 0.0027
# Epoch [16/25], Step [640/647], Loss: 0.0023
# End of epoch
# Epoch [17/25], Step [10/647], Loss: 0.0014
# Epoch [17/25], Step [20/647], Loss: 0.0026
# Epoch [17/25], Step [30/647], Loss: 0.0011
# Epoch [17/25], Step [40/647], Loss: 0.0018
# Epoch [17/25], Step [50/647], Loss: 0.0016
# Epoch [17/25], Step [60/647], Loss: 0.0026
# Epoch [17/25], Step [70/647], Loss: 0.0014
# Epoch [17/25], Step [80/647], Loss: 0.0015
# Epoch [17/25], Step [90/647], Loss: 0.0015
# Epoch [17/25], Step [100/647], Loss: 0.0027
# Epoch [17/25], Step [110/647], Loss: 0.0028
# Epoch [17/25], Step [120/647], Loss: 0.0020
# Epoch [17/25], Step [130/647], Loss: 0.0028
# Epoch [17/25], Step [140/647], Loss: 0.0016
# Epoch [17/25], Step [150/647], Loss: 0.0042
# Epoch [17/25], Step [160/647], Loss: 0.0014
# Epoch [17/25], Step [170/647], Loss: 0.0017
# Epoch [17/25], Step [180/647], Loss: 0.0016
# Epoch [17/25], Step [190/647], Loss: 0.0008
# Epoch [17/25], Step [200/647], Loss: 0.0010
# Epoch [17/25], Step [210/647], Loss: 0.0023
# Epoch [17/25], Step [220/647], Loss: 0.0026
# Epoch [17/25], Step [230/647], Loss: 0.0021
# Epoch [17/25], Step [240/647], Loss: 0.0018
# Epoch [17/25], Step [250/647], Loss: 0.0021
# Epoch [17/25], Step [260/647], Loss: 0.0015
# Epoch [17/25], Step [270/647], Loss: 0.0020
# Epoch [17/25], Step [280/647], Loss: 0.0022
# Epoch [17/25], Step [290/647], Loss: 0.0014
# Epoch [17/25], Step [300/647], Loss: 0.0021
# Epoch [17/25], Step [310/647], Loss: 0.0021
# Epoch [17/25], Step [320/647], Loss: 0.0025
# Epoch [17/25], Step [330/647], Loss: 0.0015
# Epoch [17/25], Step [340/647], Loss: 0.0012
# Epoch [17/25], Step [350/647], Loss: 0.0034
# Epoch [17/25], Step [360/647], Loss: 0.0027
# Epoch [17/25], Step [370/647], Loss: 0.0017
# Epoch [17/25], Step [380/647], Loss: 0.0014
# Epoch [17/25], Step [390/647], Loss: 0.0013
# Epoch [17/25], Step [400/647], Loss: 0.0022
# Epoch [17/25], Step [410/647], Loss: 0.0020
# Epoch [17/25], Step [420/647], Loss: 0.0013
# Epoch [17/25], Step [430/647], Loss: 0.0029
# Epoch [17/25], Step [440/647], Loss: 0.0014
# Epoch [17/25], Step [450/647], Loss: 0.0015
# Epoch [17/25], Step [460/647], Loss: 0.0015
# Epoch [17/25], Step [470/647], Loss: 0.0020
# Epoch [17/25], Step [480/647], Loss: 0.0024
# Epoch [17/25], Step [490/647], Loss: 0.0039
# Epoch [17/25], Step [500/647], Loss: 0.0022
# Epoch [17/25], Step [510/647], Loss: 0.0018
# Epoch [17/25], Step [520/647], Loss: 0.0015
# Epoch [17/25], Step [530/647], Loss: 0.0022
# Epoch [17/25], Step [540/647], Loss: 0.0024
# Epoch [17/25], Step [550/647], Loss: 0.0025
# Epoch [17/25], Step [560/647], Loss: 0.0017
# Epoch [17/25], Step [570/647], Loss: 0.0023
# Epoch [17/25], Step [580/647], Loss: 0.0021
# Epoch [17/25], Step [590/647], Loss: 0.0015
# Epoch [17/25], Step [600/647], Loss: 0.0013
# Epoch [17/25], Step [610/647], Loss: 0.0015
# Epoch [17/25], Step [620/647], Loss: 0.0029
# Epoch [17/25], Step [630/647], Loss: 0.0013
# Epoch [17/25], Step [640/647], Loss: 0.0028
# End of epoch
# Epoch [18/25], Step [10/647], Loss: 0.0024
# Epoch [18/25], Step [20/647], Loss: 0.0033
# Epoch [18/25], Step [30/647], Loss: 0.0022
# Epoch [18/25], Step [40/647], Loss: 0.0024
# Epoch [18/25], Step [50/647], Loss: 0.0013
# Epoch [18/25], Step [60/647], Loss: 0.0016
# Epoch [18/25], Step [70/647], Loss: 0.0018
# Epoch [18/25], Step [80/647], Loss: 0.0016
# Epoch [18/25], Step [90/647], Loss: 0.0029
# ...
# Epoch [20/25], Step [220/647], Loss: 0.0018
# Epoch [20/25], Step [230/647], Loss: 0.0014
# Epoch [20/25], Step [240/647], Loss: 0.0018
# Epoch [20/25], Step [250/647], Loss: 0.0020
# Epoch [20/25], Step [260/647], Loss: 0.0012
# Epoch [20/25], Step [270/647], Loss: 0.0013
# Epoch [20/25], Step [280/647], Loss: 0.0020
# Epoch [20/25], Step [290/647], Loss: 0.0014
# Epoch [20/25], Step [300/647], Loss: 0.0016
# Epoch [20/25], Step [310/647], Loss: 0.0014
# Epoch [20/25], Step [320/647], Loss: 0.0024
# Epoch [20/25], Step [330/647], Loss: 0.0023
# Epoch [20/25], Step [340/647], Loss: 0.0025
# Epoch [20/25], Step [350/647], Loss: 0.0027
# Epoch [20/25], Step [360/647], Loss: 0.0009
# Epoch [20/25], Step [370/647], Loss: 0.0010
# Epoch [20/25], Step [380/647], Loss: 0.0014
# Epoch [20/25], Step [390/647], Loss: 0.0019
# Epoch [20/25], Step [400/647], Loss: 0.0018
# Epoch [20/25], Step [410/647], Loss: 0.0018
# Epoch [20/25], Step [420/647], Loss: 0.0012
# Epoch [20/25], Step [430/647], Loss: 0.0018
# Epoch [20/25], Step [440/647], Loss: 0.0010
# Epoch [20/25], Step [450/647], Loss: 0.0023
# Epoch [20/25], Step [460/647], Loss: 0.0019
# Epoch [20/25], Step [470/647], Loss: 0.0017
# Epoch [20/25], Step [480/647], Loss: 0.0013
# Epoch [20/25], Step [490/647], Loss: 0.0022
# Epoch [20/25], Step [500/647], Loss: 0.0023
# Epoch [20/25], Step [510/647], Loss: 0.0029
# Epoch [20/25], Step [520/647], Loss: 0.0019
# Epoch [20/25], Step [530/647], Loss: 0.0024
# Epoch [20/25], Step [540/647], Loss: 0.0018
# Epoch [20/25], Step [550/647], Loss: 0.0019
# Epoch [20/25], Step [560/647], Loss: 0.0012
# Epoch [20/25], Step [570/647], Loss: 0.0011
# Epoch [20/25], Step [580/647], Loss: 0.0017
# Epoch [20/25], Step [590/647], Loss: 0.0019
# Epoch [20/25], Step [600/647], Loss: 0.0010
# Epoch [20/25], Step [610/647], Loss: 0.0035
# Epoch [20/25], Step [620/647], Loss: 0.0024
# Epoch [20/25], Step [630/647], Loss: 0.0011
# Epoch [20/25], Step [640/647], Loss: 0.0022
# End of epoch
# Epoch [21/25], Step [10/647], Loss: 0.0022
# Epoch [21/25], Step [20/647], Loss: 0.0017
# Epoch [21/25], Step [30/647], Loss: 0.0028
# Epoch [21/25], Step [40/647], Loss: 0.0010
# Epoch [21/25], Step [50/647], Loss: 0.0013
# Epoch [21/25], Step [60/647], Loss: 0.0012
# Epoch [21/25], Step [70/647], Loss: 0.0015
# Epoch [21/25], Step [80/647], Loss: 0.0017
# Epoch [21/25], Step [90/647], Loss: 0.0027
# Epoch [21/25], Step [100/647], Loss: 0.0033
# Epoch [21/25], Step [110/647], Loss: 0.0018
# Epoch [21/25], Step [120/647], Loss: 0.0016
# Epoch [21/25], Step [130/647], Loss: 0.0014
# Epoch [21/25], Step [140/647], Loss: 0.0008
# Epoch [21/25], Step [150/647], Loss: 0.0018
# Epoch [21/25], Step [160/647], Loss: 0.0010
# Epoch [21/25], Step [170/647], Loss: 0.0013
# Epoch [21/25], Step [180/647], Loss: 0.0020
# Epoch [21/25], Step [190/647], Loss: 0.0019
# Epoch [21/25], Step [200/647], Loss: 0.0024
# Epoch [21/25], Step [210/647], Loss: 0.0018
# Epoch [21/25], Step [220/647], Loss: 0.0029
# Epoch [21/25], Step [230/647], Loss: 0.0018
# Epoch [21/25], Step [240/647], Loss: 0.0022
# Epoch [21/25], Step [250/647], Loss: 0.0015
# Epoch [21/25], Step [260/647], Loss: 0.0019
# Epoch [21/25], Step [270/647], Loss: 0.0024
# Epoch [21/25], Step [280/647], Loss: 0.0017
# Epoch [21/25], Step [290/647], Loss: 0.0040
# Epoch [21/25], Step [300/647], Loss: 0.0017
# Epoch [21/25], Step [310/647], Loss: 0.0035
# Epoch [21/25], Step [320/647], Loss: 0.0027
# Epoch [21/25], Step [330/647], Loss: 0.0017
# Epoch [21/25], Step [340/647], Loss: 0.0030
# Epoch [21/25], Step [350/647], Loss: 0.0017
# Epoch [21/25], Step [360/647], Loss: 0.0013
# Epoch [21/25], Step [370/647], Loss: 0.0014
# Epoch [21/25], Step [380/647], Loss: 0.0015
# Epoch [21/25], Step [390/647], Loss: 0.0024
# Epoch [21/25], Step [400/647], Loss: 0.0023
# Epoch [21/25], Step [410/647], Loss: 0.0012
# Epoch [21/25], Step [420/647], Loss: 0.0034
# Epoch [21/25], Step [430/647], Loss: 0.0013
# Epoch [21/25], Step [440/647], Loss: 0.0020
# Epoch [21/25], Step [450/647], Loss: 0.0038
# Epoch [21/25], Step [460/647], Loss: 0.0009
# Epoch [21/25], Step [470/647], Loss: 0.0029
# Epoch [21/25], Step [480/647], Loss: 0.0009
# Epoch [21/25], Step [490/647], Loss: 0.0014
# Epoch [21/25], Step [500/647], Loss: 0.0014
# Epoch [21/25], Step [510/647], Loss: 0.0018
# Epoch [21/25], Step [520/647], Loss: 0.0017
# Epoch [21/25], Step [530/647], Loss: 0.0022
# Epoch [21/25], Step [540/647], Loss: 0.0017
# Epoch [21/25], Step [550/647], Loss: 0.0015
# Epoch [21/25], Step [560/647], Loss: 0.0022
# Epoch [21/25], Step [570/647], Loss: 0.0008
# Epoch [21/25], Step [580/647], Loss: 0.0013
# Epoch [21/25], Step [590/647], Loss: 0.0010
# Epoch [21/25], Step [600/647], Loss: 0.0018
# Epoch [21/25], Step [610/647], Loss: 0.0016
# Epoch [21/25], Step [620/647], Loss: 0.0021
# Epoch [21/25], Step [630/647], Loss: 0.0026
# Epoch [21/25], Step [640/647], Loss: 0.0016
# End of epoch
# Epoch [22/25], Step [10/647], Loss: 0.0020
# Epoch [22/25], Step [20/647], Loss: 0.0014
# Epoch [22/25], Step [30/647], Loss: 0.0017
# Epoch [22/25], Step [40/647], Loss: 0.0023
# Epoch [22/25], Step [50/647], Loss: 0.0016
# Epoch [22/25], Step [60/647], Loss: 0.0013
# Epoch [22/25], Step [70/647], Loss: 0.0014
# Epoch [22/25], Step [80/647], Loss: 0.0023
# Epoch [22/25], Step [90/647], Loss: 0.0018
# Epoch [22/25], Step [100/647], Loss: 0.0029
# Epoch [22/25], Step [110/647], Loss: 0.0017
# Epoch [22/25], Step [120/647], Loss: 0.0013
# Epoch [22/25], Step [130/647], Loss: 0.0025
# Epoch [22/25], Step [140/647], Loss: 0.0035
# Epoch [22/25], Step [150/647], Loss: 0.0028
# Epoch [22/25], Step [160/647], Loss: 0.0033
# Epoch [22/25], Step [170/647], Loss: 0.0026
# Epoch [22/25], Step [180/647], Loss: 0.0018
# Epoch [22/25], Step [190/647], Loss: 0.0012
# Epoch [22/25], Step [200/647], Loss: 0.0015
# Epoch [22/25], Step [210/647], Loss: 0.0016
# Epoch [22/25], Step [220/647], Loss: 0.0014
# Epoch [22/25], Step [230/647], Loss: 0.0020
# Epoch [22/25], Step [240/647], Loss: 0.0014
# Epoch [22/25], Step [250/647], Loss: 0.0023
# Epoch [22/25], Step [260/647], Loss: 0.0017
# Epoch [22/25], Step [270/647], Loss: 0.0018
# Epoch [22/25], Step [280/647], Loss: 0.0021
# Epoch [22/25], Step [290/647], Loss: 0.0023
# Epoch [22/25], Step [300/647], Loss: 0.0011
# Epoch [22/25], Step [310/647], Loss: 0.0020
# Epoch [22/25], Step [320/647], Loss: 0.0008
# Epoch [22/25], Step [330/647], Loss: 0.0014
# Epoch [22/25], Step [340/647], Loss: 0.0015
# Epoch [22/25], Step [350/647], Loss: 0.0019
# Epoch [22/25], Step [360/647], Loss: 0.0016
# Epoch [22/25], Step [370/647], Loss: 0.0017
# Epoch [22/25], Step [380/647], Loss: 0.0016
# Epoch [22/25], Step [390/647], Loss: 0.0026
# Epoch [22/25], Step [400/647], Loss: 0.0030
# Epoch [22/25], Step [410/647], Loss: 0.0014
# Epoch [22/25], Step [420/647], Loss: 0.0010
# Epoch [22/25], Step [430/647], Loss: 0.0036
# Epoch [22/25], Step [440/647], Loss: 0.0028
# Epoch [22/25], Step [450/647], Loss: 0.0012
# Epoch [22/25], Step [460/647], Loss: 0.0019
# Epoch [22/25], Step [470/647], Loss: 0.0032
# Epoch [22/25], Step [480/647], Loss: 0.0017
# Epoch [22/25], Step [490/647], Loss: 0.0020
# Epoch [22/25], Step [500/647], Loss: 0.0012
# Epoch [22/25], Step [510/647], Loss: 0.0022
# Epoch [22/25], Step [520/647], Loss: 0.0025
# Epoch [22/25], Step [530/647], Loss: 0.0012
# Epoch [22/25], Step [540/647], Loss: 0.0014
# Epoch [22/25], Step [550/647], Loss: 0.0023
# Epoch [22/25], Step [560/647], Loss: 0.0023
# Epoch [22/25], Step [570/647], Loss: 0.0013
# Epoch [22/25], Step [580/647], Loss: 0.0019
# Epoch [22/25], Step [590/647], Loss: 0.0019
# Epoch [22/25], Step [600/647], Loss: 0.0017
# Epoch [22/25], Step [610/647], Loss: 0.0026
# Epoch [22/25], Step [620/647], Loss: 0.0018
# Epoch [22/25], Step [630/647], Loss: 0.0017
# Epoch [22/25], Step [640/647], Loss: 0.0019
# End of epoch
# Epoch [23/25], Step [10/647], Loss: 0.0030
# Epoch [23/25], Step [20/647], Loss: 0.0035
# Epoch [23/25], Step [30/647], Loss: 0.0013
# Epoch [23/25], Step [40/647], Loss: 0.0022
# Epoch [23/25], Step [50/647], Loss: 0.0030
# Epoch [23/25], Step [60/647], Loss: 0.0013
# Epoch [23/25], Step [70/647], Loss: 0.0019
# Epoch [23/25], Step [80/647], Loss: 0.0011
# Epoch [23/25], Step [90/647], Loss: 0.0027
# Epoch [23/25], Step [100/647], Loss: 0.0010
# Epoch [23/25], Step [110/647], Loss: 0.0028
# Epoch [23/25], Step [120/647], Loss: 0.0015
# Epoch [23/25], Step [130/647], Loss: 0.0015
# Epoch [23/25], Step [140/647], Loss: 0.0027
# Epoch [23/25], Step [150/647], Loss: 0.0014
# Epoch [23/25], Step [160/647], Loss: 0.0014
# Epoch [23/25], Step [170/647], Loss: 0.0017
# Epoch [23/25], Step [180/647], Loss: 0.0011
# Epoch [23/25], Step [190/647], Loss: 0.0040
# Epoch [23/25], Step [200/647], Loss: 0.0010
# Epoch [23/25], Step [210/647], Loss: 0.0023
# Epoch [23/25], Step [220/647], Loss: 0.0016
# Epoch [23/25], Step [230/647], Loss: 0.0024
# Epoch [23/25], Step [240/647], Loss: 0.0015
# Epoch [23/25], Step [250/647], Loss: 0.0041
# Epoch [23/25], Step [260/647], Loss: 0.0028
# Epoch [23/25], Step [270/647], Loss: 0.0035
# Epoch [23/25], Step [280/647], Loss: 0.0021
# Epoch [23/25], Step [290/647], Loss: 0.0010
# Epoch [23/25], Step [300/647], Loss: 0.0010
# Epoch [23/25], Step [310/647], Loss: 0.0030
# Epoch [23/25], Step [320/647], Loss: 0.0019
# Epoch [23/25], Step [330/647], Loss: 0.0010
# Epoch [23/25], Step [340/647], Loss: 0.0014
# Epoch [23/25], Step [350/647], Loss: 0.0008
# Epoch [23/25], Step [360/647], Loss: 0.0026
# Epoch [23/25], Step [370/647], Loss: 0.0029
# Epoch [23/25], Step [380/647], Loss: 0.0018
# Epoch [23/25], Step [390/647], Loss: 0.0013
# Epoch [23/25], Step [400/647], Loss: 0.0020
# Epoch [23/25], Step [410/647], Loss: 0.0010
# Epoch [23/25], Step [420/647], Loss: 0.0019
# Epoch [23/25], Step [430/647], Loss: 0.0031
# Epoch [23/25], Step [440/647], Loss: 0.0020
# Epoch [23/25], Step [450/647], Loss: 0.0019
# Epoch [23/25], Step [460/647], Loss: 0.0018
# Epoch [23/25], Step [470/647], Loss: 0.0015
# Epoch [23/25], Step [480/647], Loss: 0.0017
# Epoch [23/25], Step [490/647], Loss: 0.0011
# Epoch [23/25], Step [500/647], Loss: 0.0017
# Epoch [23/25], Step [510/647], Loss: 0.0011
# Epoch [23/25], Step [520/647], Loss: 0.0016
# Epoch [23/25], Step [530/647], Loss: 0.0028
# Epoch [23/25], Step [540/647], Loss: 0.0016
# Epoch [23/25], Step [550/647], Loss: 0.0016
# Epoch [23/25], Step [560/647], Loss: 0.0013
# Epoch [23/25], Step [570/647], Loss: 0.0018
# Epoch [23/25], Step [580/647], Loss: 0.0010
# Epoch [23/25], Step [590/647], Loss: 0.0018
# Epoch [23/25], Step [600/647], Loss: 0.0015
# Epoch [23/25], Step [610/647], Loss: 0.0023
# Epoch [23/25], Step [620/647], Loss: 0.0011
# Epoch [23/25], Step [630/647], Loss: 0.0023
# Epoch [23/25], Step [640/647], Loss: 0.0014
# End of epoch
# Epoch [24/25], Step [10/647], Loss: 0.0016
# Epoch [24/25], Step [20/647], Loss: 0.0020
# Epoch [24/25], Step [30/647], Loss: 0.0018
# Epoch [24/25], Step [40/647], Loss: 0.0022
# Epoch [24/25], Step [50/647], Loss: 0.0019
# Epoch [24/25], Step [60/647], Loss: 0.0011
# Epoch [24/25], Step [70/647], Loss: 0.0020
# Epoch [24/25], Step [80/647], Loss: 0.0013
# Epoch [24/25], Step [90/647], Loss: 0.0014
# Epoch [24/25], Step [100/647], Loss: 0.0022
# Epoch [24/25], Step [110/647], Loss: 0.0017
# Epoch [24/25], Step [120/647], Loss: 0.0040
# Epoch [24/25], Step [130/647], Loss: 0.0014
# Epoch [24/25], Step [140/647], Loss: 0.0016
# Epoch [24/25], Step [150/647], Loss: 0.0015
# Epoch [24/25], Step [160/647], Loss: 0.0049
# Epoch [24/25], Step [170/647], Loss: 0.0016
# Epoch [24/25], Step [180/647], Loss: 0.0023
# Epoch [24/25], Step [190/647], Loss: 0.0010
# Epoch [24/25], Step [200/647], Loss: 0.0034
# Epoch [24/25], Step [210/647], Loss: 0.0011
# Epoch [24/25], Step [220/647], Loss: 0.0010
# Epoch [24/25], Step [230/647], Loss: 0.0014
# Epoch [24/25], Step [240/647], Loss: 0.0033
# Epoch [24/25], Step [250/647], Loss: 0.0020
# Epoch [24/25], Step [260/647], Loss: 0.0017
# Epoch [24/25], Step [270/647], Loss: 0.0017
# Epoch [24/25], Step [280/647], Loss: 0.0019
# Epoch [24/25], Step [290/647], Loss: 0.0031
# Epoch [24/25], Step [300/647], Loss: 0.0032
# Epoch [24/25], Step [310/647], Loss: 0.0030
# Epoch [24/25], Step [320/647], Loss: 0.0013
# Epoch [24/25], Step [330/647], Loss: 0.0013
# Epoch [24/25], Step [340/647], Loss: 0.0022
# Epoch [24/25], Step [350/647], Loss: 0.0017
# Epoch [24/25], Step [360/647], Loss: 0.0013
# Epoch [24/25], Step [370/647], Loss: 0.0014
# Epoch [24/25], Step [380/647], Loss: 0.0022
# Epoch [24/25], Step [390/647], Loss: 0.0033
# Epoch [24/25], Step [400/647], Loss: 0.0014
# Epoch [24/25], Step [410/647], Loss: 0.0015
# Epoch [24/25], Step [420/647], Loss: 0.0012
# Epoch [24/25], Step [430/647], Loss: 0.0010
# Epoch [24/25], Step [440/647], Loss: 0.0015
# Epoch [24/25], Step [450/647], Loss: 0.0015
# Epoch [24/25], Step [460/647], Loss: 0.0015
# Epoch [24/25], Step [470/647], Loss: 0.0010
# Epoch [24/25], Step [480/647], Loss: 0.0021
# Epoch [24/25], Step [490/647], Loss: 0.0016
# Epoch [24/25], Step [500/647], Loss: 0.0021
# Epoch [24/25], Step [510/647], Loss: 0.0017
# Epoch [24/25], Step [520/647], Loss: 0.0016
# Epoch [24/25], Step [530/647], Loss: 0.0020
# Epoch [24/25], Step [540/647], Loss: 0.0013
# Epoch [24/25], Step [550/647], Loss: 0.0024
# Epoch [24/25], Step [560/647], Loss: 0.0010
# Epoch [24/25], Step [570/647], Loss: 0.0032
# Epoch [24/25], Step [580/647], Loss: 0.0032
# Epoch [24/25], Step [590/647], Loss: 0.0010
# Epoch [24/25], Step [600/647], Loss: 0.0014
# Epoch [24/25], Step [610/647], Loss: 0.0017
# Epoch [24/25], Step [620/647], Loss: 0.0013
# Epoch [24/25], Step [630/647], Loss: 0.0017
# Epoch [24/25], Step [640/647], Loss: 0.0022
# End of epoch
# Epoch [25/25], Step [10/647], Loss: 0.0010
# Epoch [25/25], Step [20/647], Loss: 0.0019
# Epoch [25/25], Step [30/647], Loss: 0.0022
# Epoch [25/25], Step [40/647], Loss: 0.0012
# Epoch [25/25], Step [50/647], Loss: 0.0021
# Epoch [25/25], Step [60/647], Loss: 0.0031
# Epoch [25/25], Step [70/647], Loss: 0.0017
# Epoch [25/25], Step [80/647], Loss: 0.0008
# Epoch [25/25], Step [90/647], Loss: 0.0010
# Epoch [25/25], Step [100/647], Loss: 0.0014
# Epoch [25/25], Step [110/647], Loss: 0.0035
# Epoch [25/25], Step [120/647], Loss: 0.0028
# Epoch [25/25], Step [130/647], Loss: 0.0016
# Epoch [25/25], Step [140/647], Loss: 0.0020
# Epoch [25/25], Step [150/647], Loss: 0.0018
# Epoch [25/25], Step [160/647], Loss: 0.0028
# Epoch [25/25], Step [170/647], Loss: 0.0024
# Epoch [25/25], Step [180/647], Loss: 0.0007
# Epoch [25/25], Step [190/647], Loss: 0.0010
# Epoch [25/25], Step [200/647], Loss: 0.0014
# Epoch [25/25], Step [210/647], Loss: 0.0024
# Epoch [25/25], Step [220/647], Loss: 0.0039
# Epoch [25/25], Step [230/647], Loss: 0.0024
# Epoch [25/25], Step [240/647], Loss: 0.0018
# Epoch [25/25], Step [250/647], Loss: 0.0025
# Epoch [25/25], Step [260/647], Loss: 0.0013
# Epoch [25/25], Step [270/647], Loss: 0.0020
# Epoch [25/25], Step [280/647], Loss: 0.0014
# Epoch [25/25], Step [290/647], Loss: 0.0011
# Epoch [25/25], Step [300/647], Loss: 0.0019
# Epoch [25/25], Step [310/647], Loss: 0.0023
# Epoch [25/25], Step [320/647], Loss: 0.0021
# Epoch [25/25], Step [330/647], Loss: 0.0013
# Epoch [25/25], Step [340/647], Loss: 0.0016
# Epoch [25/25], Step [350/647], Loss: 0.0025
# Epoch [25/25], Step [360/647], Loss: 0.0021
# Epoch [25/25], Step [370/647], Loss: 0.0020
# Epoch [25/25], Step [380/647], Loss: 0.0032
# Epoch [25/25], Step [390/647], Loss: 0.0013
# Epoch [25/25], Step [400/647], Loss: 0.0019
# Epoch [25/25], Step [410/647], Loss: 0.0018
# Epoch [25/25], Step [420/647], Loss: 0.0027
# Epoch [25/25], Step [430/647], Loss: 0.0012
# Epoch [25/25], Step [440/647], Loss: 0.0018
# Epoch [25/25], Step [450/647], Loss: 0.0018
# Epoch [25/25], Step [460/647], Loss: 0.0018
# Epoch [25/25], Step [470/647], Loss: 0.0016
# Epoch [25/25], Step [480/647], Loss: 0.0016
# Epoch [25/25], Step [490/647], Loss: 0.0013
# Epoch [25/25], Step [500/647], Loss: 0.0009
# Epoch [25/25], Step [510/647], Loss: 0.0023
# Epoch [25/25], Step [520/647], Loss: 0.0025
# Epoch [25/25], Step [530/647], Loss: 0.0013
# Epoch [25/25], Step [540/647], Loss: 0.0019
# Epoch [25/25], Step [550/647], Loss: 0.0023
# Epoch [25/25], Step [560/647], Loss: 0.0017
# Epoch [25/25], Step [570/647], Loss: 0.0018
# Epoch [25/25], Step [580/647], Loss: 0.0020
# Epoch [25/25], Step [590/647], Loss: 0.0019
# Epoch [25/25], Step [600/647], Loss: 0.0013
# Epoch [25/25], Step [610/647], Loss: 0.0016
# Epoch [25/25], Step [620/647], Loss: 0.0020
# Epoch [25/25], Step [630/647], Loss: 0.0015
# Epoch [25/25], Step [640/647], Loss: 0.0009

# %%
hours_elapsed = ((end-start)/3600)
print("Model Training took ", hours_elapsed, "hours")
# Out:
# Model Training took  19.441433211565016 hours

# %%
plt.figure(figsize=(8,8))
plt.subplot(212)
plt.plot(range(len(epoch_loss)), epoch_loss)
plt.xlabel('Training Epoch')
plt.ylabel('Train Loss Value')
plt.savefig('/content/drive/MyDrive/CT_Project/trainlos_var.png')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.subplot(212)
plt.plot(range(len(train_acc)), train_acc)
plt.xlabel('Training Epoch')
plt.ylabel('Train Set MSE Value')
plt.savefig('/content/drive/MyDrive/CT_Project/trainacc_var.png')
plt.show()

# %% [markdown]
# # **4th Part: Testing**
#
# model.pt = 3x3 Kernels
#
# model2.pt = 5x5 Kernels
#
# model_tr.pt = 3x3 Kernels with Transforms
#
# model_var_ker.pt = 3x3 -> 5x5 -> 7x7 -> 5x5 -> 3x3 kernels with Transforms

# %%
error, noisy_error, denoised, LDCT, image = test(model, test_loader, loss_fn,  batch_size = 1, sample_idx = 7, device = None, PATH = '/content/drive/MyDrive/CT_Project/model_tr.pt')
# Out:
# Average MSE Loss =  0.0006264194401693438

# %%
plt.imshow(image.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(denoised.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(LDCT.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
print("There were ",len(error), "Low-dose CT (LDCT) scans analyzed in the hold-out test set:")
print("\n")
print("\n")
print("The mean MSE for the LDCT scans was ", statistics.mean(noisy_error), "+-", statistics.stdev(noisy_error))
print("The highest MSE error for  LDCT scans was ",max(noisy_error), "and the minimum was", min(noisy_error))
print("\n")
print("The mean MSE for the Denoised LDCT scans was ", statistics.mean(error), "+-", statistics.stdev(error))
print("The highest MSE error for Denoised LDCT scans was ",max(error), "and the minimum was", min(error))
# Out:
# There were  151 Low-dose CT (LDCT) scans analyzed in the hold-out test set:
#
#
#
#
# The mean MSE for the LDCT scans was  0.0002184237475123022 +- 4.871378081278243e-05
# The highest MSE error for  LDCT scans was  0.00031968712573871017 and the minimum was 0.0001040740025928244
#
#
# The mean MSE for the Denoised LDCT scans was  0.0006264194401693438 +- 0.0004430044908059579
# The highest MSE error for Denoised LDCT scans was  0.0018470900831744075 and the minimum was 0.0001953792234417051

# %%
### Previous Testing with other models

# %%
error, noisy_error, denoised, LDCT, image = test(model, test_loader, loss_fn,  batch_size = 1, sample_idx = 7, device = None, PATH = '/content/drive/MyDrive/CT_Project/model_var_ker.pt')
# Out:
# Average MSE Loss =  0.0030986991308518492

# %%
plt.imshow(image.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(denoised.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(LDCT.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
error, noisy_error, denoised, LDCT, image = test(model, test_loader, loss_fn,  batch_size = 1, device = None, PATH = '/content/drive/MyDrive/CT_Project/model2.pt')
# Out:
# Average MSE Loss =  0.001157823719534505

# %%
plt.imshow(image.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(denoised.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(LDCT.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
error, noisy_error, denoised, LDCT, image = test(model, test_loader, loss_fn,  batch_size = 1, device = None, PATH = '/content/drive/MyDrive/CT_Project/model_tr.pt')
# Out:
# Average MSE Loss =  0.0006258703472589248

# %%
plt.imshow(image.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(denoised.cpu()[0][0],cmap='gray',vmin=0,vmax=1)

# %%
plt.imshow(LDCT.cpu()[0][0],cmap='gray',vmin=0,vmax=1)
